# %%
# Run in python console
import nltk; nltk.download('stopwords')

# Run in terminal or command prompt
#python3 -m spacy download en
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Zach\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
#import pyLDAvis
#import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline


from google_play_scraper import Sort, reviews, reviews_all, app

# %%
result, _ = reviews(
    'com.plarium.raidlegends',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT, NEWEST
    count=1000, # defaults to 100
    filter_score_with=None # defaults to None(means all score)
)

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
df = pd.DataFrame([x for x in result])
#df['content'] = df['content'].str.replace('[^a-zA-Z ]', '').str.lower()

# %%
df.head()
# Out:
#                                             reviewId        userName  \
# 0  gp:AOqpTOFUFv_VfMRd7N5dY-A7dLDbACm2sOY4HgL-37q...   Darius Glemza
# 1  gp:AOqpTOFDG3mv7_ylqYDQfp29i6qVblWkFMf01lwWFaI...             A S
# 2  gp:AOqpTOFXZox7A1T25DlGsPyf_Kg3sWzyJqBmmCKjRJ4...  Isaac Williams
# 3  gp:AOqpTOH5qtDqKwJ846lBqx8A2muB4iwsa8706MqDfUp...  Leonard Vaughn
# 4  gp:AOqpTOFTYdB4aVpsQYRgPVJefqOo5QD6uZPjnAVzlxv...       Travis M.
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a/AATXAJ...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a/AATXAJ...
# 4  https://play-lh.googleusercontent.com/a/AATXAJ...
#
#                                              content  score  thumbsUpCount  \
# 0  Was fun while it worked, been playing for almo...      3             10
# 1  The game is fun to play, but has a serious pro...      2             58
# 2  The game itself is pretty okay but with some r...      2             70
# 3  Great game and is the only phone app game ive ...      5              8
# 4  The game is fine. Don't ever spend a dime, the...      2             37
#
#   reviewCreatedVersion                  at  \
# 0               4.60.2 2021-10-07 20:27:02
# 1               4.70.0 2021-10-05 08:28:40
# 2               4.70.0 2021-10-06 00:03:06
# 3               4.70.0 2021-10-05 08:11:39
# 4               4.70.0 2021-10-05 15:26:11
#
#                                         replyContent           repliedAt
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4  Hello, Travis! We decided to include guarantee... 2021-07-30 09:13:44

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
data_words = list(sent_to_words(df['content']))

# %%
data_words
# Out:
# [['was',
#   'fun',
#   'while',
#   'it',
#   'worked',
#   'been',
#   'playing',
#   'for',
#   'almost',
#   'weeks',
#   'and',
#   'it',
#   'has',
#   'lot',
#   'of',
#   'potential',
#   'plenty',
#   'of',
#   'options',
#   'for',
#   'free',
#   'to',
#   'play',
#   'and',
#   'limited',
#   'pay',
#   'to',
#   'play',
#   'style',
#   'of',
#   'players',
#   'unfortunately',
#   'starting',
#   'late',
#   'last',
#   'night',
#   'was',
#   'unable',
#   'to',
#   'login',
#   'and',
#   'tried',
#   'the',
#   'usual',
#   'fixes',
#   'clearing',
#   'cache',
#   'uninstall',
#   'contact',
#   'support',
#   'but',
#   'support',
#   'has',
#   'yet',
#   'to',
#   'get',
#   'in',
#   'contact',
#   'with',
#   'me',
#   'it',
#   'been',
#   'approximately',
#   'hrs',
#   'and',
#   'still',
#   'nothing',
#   'glad',
#   'don',
#   'have',
#   'too',
#   'much',
#   'vested',
#   'in',
#   'this',
#   'game',
#   'or',
#   'would',
#   'be',
#   'very',
#   'upset'],
#  ['the',
#   'game',
#   'is',
#   'fun',
#   'to',
#   'play',
#   'but',
#   'has',
#   'serious',
#   'problem',
#   'after',
#   'you',
#   'build',
#   'champion',
#   'spending',
#   'your',
#   'time',
#   'effort',
#   'and',
#   'real',
#   'money',
#   'the',
#   'company',
#   'nerf',
#   'the',
#   'champion',
#   'and',
#   'make',
#   'it',
#   'almost',
#   'useless',
#   'then',
#   'you',
#   'start',
#   'again',
#   'spending',
#   'to',
#   'get',
#   'new',
#   'champion',
#   'again',
#   'invest',
#   'your',
#   'time',
#   'and',
#   'effort',
#   'to',
#   'build',
#   'it',
#   'and',
#   'at',
#   'the',
#   'end',
#   'there',
#   'is',
#   'no',
#   'surity',
#   'that',
#   'the',
#   'company',
#   'will',
#   'not',
#   'nerf',
#   'it',
#   'agin',
#   'at',
#   'the',
#   'next',
#   'update',
#   'they',
#   'did',
#   'this',
#   'several',
#   'times',
#   'already',
#   'and',
#   'you',
#   'can',
#   'do',
#   'nothing',
#   'as',
#   'it',
#   'is',
#   'mentioned',
#   'in',
#   'their',
#   'terms',
#   'and',
#   'conditions'],
#  ['the',
#   'game',
#   'itself',
#   'is',
#   'pretty',
#   'okay',
#   'but',
#   'with',
#   'some',
#   'recent',
#   'things',
#   'that',
#   'have',
#   'happened',
#   'notably',
#   'gutting',
#   'champion',
#   'shortly',
#   'after',
#   'tons',
#   'of',
#   'people',
#   'invested',
#   'lot',
#   'of',
#   'resources',
#   'into',
#   'and',
#   'nerfing',
#   'another',
#   'champion',
#   'with',
#   'no',
#   'prior',
#   'warning',
#   'can',
#   'recommend',
#   'anyone',
#   'play',
#   'this',
#   'at',
#   'the',
#   'moment',
#   'and',
#   'for',
#   'those',
#   'who',
#   'are',
#   'going',
#   'to',
#   'start',
#   'keep',
#   'playing',
#   'don',
#   'spend',
#   'money',
#   'on',
#   'this',
#   'game',
#   'it',
#   'just',
#   'not',
#   'worth',
#   'it',
#   'with',
#   'how',
#   'plarium',
#   'been',
#   'running',
#   'the',
#   'game',
#   'recently'],
#  ['great',
#   'game',
#   'and',
#   'is',
#   'the',
#   'only',
#   'phone',
#   'app',
#   'game',
#   'ive',
#   'continued',
#   'to',
#   'play',
#   'after',
#   'couple',
#   'months',
#   'and',
#   'its',
#   'been',
#   'over',
#   'year',
#   'the',
#   'only',
#   'down',
#   'side',
#   'have',
#   'is',
#   'the',
#   'same',
#   'for',
#   'most',
#   'app',
#   'games',
#   'it',
#   'can',
#   'get',
#   'pretty',
#   'one',
#   'sided',
#   'in',
#   'the',
#   'arena',
#   'where',
#   'pay',
#   'to',
#   'play',
#   'dominates',
#   'but',
#   'you',
#   'can',
#   'still',
#   'get',
#   'wins',
#   'and',
#   'climb',
#   'the',
#   'ranks',
#   'to',
#   'gold',
#   'if',
#   'careful',
#   'and',
#   'selective',
#   'of',
#   'who',
#   'you',
#   'fight',
#   'and',
#   'another',
#   'common',
#   'down',
#   'side',
#   'if',
#   'you',
#   'stay',
#   'free',
#   'play',
#   'it',
#   'will',
#   'be',
#   'difficult',
#   'and',
#   'slow',
#   'pulling',
#   'top',
#   'tier',
#   'champs',
#   'but',
#   'its',
#   'not',
#   'impossible'],
#  ['the',
#   'game',
#   'is',
#   'fine',
#   'don',
#   'ever',
#   'spend',
#   'dime',
#   'they',
#   'will',
#   'take',
#   'the',
#   'money',
#   'and',
#   'you',
#   'will',
#   'not',
#   'get',
#   'what',
#   'is',
#   'promised',
#   'in',
#   'return',
#   'don',
#   'focus',
#   'on',
#   'building',
#   'great',
#   'champions',
#   'they',
#   'nerf',
#   'them',
#   'without',
#   'notice',
#   'once',
#   'the',
#   'max',
#   'playerbase',
#   'spends',
#   'just',
#   'play',
#   'casually',
#   'spend',
#   'nothing',
#   'and',
#   'don',
#   'get',
#   'excited',
#   'about',
#   'finally',
#   'getting',
#   'an',
#   'awesome',
#   'champ',
#   'to',
#   'help',
#   'you',
#   'progress',
#   'and',
#   'the',
#   'game',
#   'will',
#   'be',
#   'enjoyable'],
#  ['played',
#   'for',
#   'years',
#   'they',
#   'had',
#   'an',
#   'issue',
#   'that',
#   'caused',
#   'me',
#   'to',
#   'loose',
#   'lot',
#   'of',
#   'progress',
#   'and',
#   'rewards',
#   'from',
#   'an',
#   'event',
#   'had',
#   'been',
#   'saving',
#   'resources',
#   'for',
#   'contacted',
#   'customer',
#   'support',
#   'and',
#   'was',
#   'basically',
#   'told',
#   'they',
#   'wouldn',
#   'do',
#   'anything',
#   'about',
#   'me',
#   'not',
#   'being',
#   'able',
#   'to',
#   'access',
#   'both',
#   'my',
#   'accounts',
#   'during',
#   'the',
#   'event',
#   'and',
#   'that',
#   'it',
#   'was',
#   'tough',
#   'luck',
#   'do',
#   'not',
#   'give',
#   'this',
#   'company',
#   'money',
#   'the',
#   'pvp',
#   'system',
#   'is',
#   'terrible',
#   'also'],
#  ['it',
#   'just',
#   'too',
#   'tedious',
#   'waste',
#   'of',
#   'time',
#   'resources',
#   'talent',
#   'and',
#   'of',
#   'course',
#   'money',
#   'an',
#   'insane',
#   'amount',
#   'of',
#   'grind',
#   'for',
#   'very',
#   'little',
#   'game',
#   'the',
#   'only',
#   'thing',
#   'it',
#   'has',
#   'going',
#   'for',
#   'it',
#   'is',
#   'some',
#   'significant',
#   'artistic',
#   'talent',
#   'and',
#   'an',
#   'entertaining',
#   'ad',
#   'campaign',
#   'the',
#   'game',
#   'isn',
#   'designed',
#   'to',
#   'be',
#   'honestly',
#   'engaging',
#   'or',
#   'fun',
#   'it',
#   'merely',
#   'designed',
#   'to',
#   'keep',
#   'people',
#   'hooked',
#   'which',
#   'of',
#   'course',
#   'is',
#   'always',
#   'such',
#   'shame'],
#  ['insane',
#   'how',
#   'they',
#   'can',
#   'make',
#   'events',
#   'and',
#   'encourage',
#   'you',
#   'to',
#   'spend',
#   'time',
#   'and',
#   'money',
#   'investing',
#   'in',
#   'certain',
#   'champions',
#   'to',
#   'just',
#   'sneakily',
#   'nerf',
#   'them',
#   'into',
#   'the',
#   'ground',
#   'without',
#   'any',
#   'mention',
#   'of',
#   'it',
#   'untill',
#   'its',
#   'done',
#   'by',
#   'far',
#   'the',
#   'most',
#   'greedy',
#   'company',
#   'with',
#   'the',
#   'most',
#   'shady',
#   'business',
#   'tactics',
#   'have',
#   'spent',
#   'thousands',
#   'of',
#   'dollars',
#   'on',
#   'the',
#   'game',
#   'over',
#   'the',
#   'past',
#   'years',
#   'and',
#   'they',
#   'have',
#   'just',
#   'been',
#   'getting',
#   'worse',
#   'and',
#   'worse',
#   'cannot',
#   'recommend',
#   'this',
#   'game',
#   'anymore',
#   'and',
#   'they',
#   'will',
#   'not',
#   'be',
#   'seeing',
#   'any',
#   'business',
#   'from',
#   'me',
#   'any',
#   'longer'],
#  ['game',
#   'is',
#   'super',
#   'fun',
#   'but',
#   'in',
#   'game',
#   'purchases',
#   'are',
#   'stupid',
#   'expensive',
#   'say',
#   'stupid',
#   'because',
#   'they',
#   'would',
#   'make',
#   'lot',
#   'more',
#   'money',
#   'if',
#   'the',
#   'packs',
#   'you',
#   'can',
#   'buy',
#   'were',
#   'each',
#   'would',
#   'buy',
#   'some',
#   'weekly',
#   'but',
#   'they',
#   'are',
#   'you',
#   'can',
#   'buy',
#   'new',
#   'game',
#   'for',
#   'that',
#   'poor',
#   'form',
#   'to',
#   'charge',
#   'that',
#   'much',
#   'to',
#   'your',
#   'loyal',
#   'game',
#   'players',
#   'insulting'],
#  ['the',
#   'best',
#   'easy',
#   'to',
#   'learn',
#   'hard',
#   'to',
#   'master',
#   'idle',
#   'rpg',
#   'on',
#   'the',
#   'market',
#   'the',
#   'sheer',
#   'volume',
#   'of',
#   'possibilities',
#   'is',
#   'astounding',
#   'from',
#   'gear',
#   'through',
#   'masteries',
#   'to',
#   'skills',
#   'every',
#   'champion',
#   'is',
#   'unique',
#   'in',
#   'some',
#   'way',
#   'and',
#   'there',
#   'are',
#   'dozens',
#   'of',
#   'approaches',
#   'to',
#   'the',
#   'challenges',
#   'presented',
#   'by',
#   'the',
#   'game',
#   'it',
#   'really',
#   'something',
#   'special',
#   'that',
#   'said',
#   'don',
#   'get',
#   'trapped',
#   'by',
#   'game',
#   'mechanics',
#   'you',
#   'don',
#   'have',
#   'to',
#   'do',
#   'every',
#   'fusion',
#   'don',
#   'open',
#   'shards',
#   'outside',
#   'of',
#   'especially',
#   'not',
#   'in',
#   'the',
#   'which',
#   'are',
#   'just',
#   'scam',
#   'aimed',
#   'at',
#   'whales',
#   'watch',
#   'youtubers'],
#  ['lvl',
#   've',
#   'played',
#   'for',
#   'long',
#   'time',
#   'rsl',
#   'is',
#   'another',
#   'game',
#   'roach',
#   'motel',
#   'designed',
#   'to',
#   'eat',
#   'or',
#   'give',
#   'no',
#   'chance',
#   'of',
#   'being',
#   'competitive',
#   'in',
#   'tournaments',
#   'events',
#   'or',
#   'arena',
#   'battles',
#   'if',
#   'you',
#   'love',
#   'being',
#   'bombarded',
#   'with',
#   'offer',
#   'after',
#   'offer',
#   'for',
#   'ridiculous',
#   'sums',
#   'of',
#   'every',
#   'single',
#   'time',
#   'you',
#   'log',
#   'in',
#   'and',
#   'knowing',
#   'pay',
#   'to',
#   'win',
#   'is',
#   'the',
#   'only',
#   'way',
#   'to',
#   'win',
#   'this',
#   'game',
#   'is',
#   'for',
#   'you',
#   'the',
#   'login',
#   'rewards',
#   'get',
#   'worse',
#   'all',
#   'the',
#   'time',
#   'and',
#   'the',
#   'packs',
#   'get',
#   'more',
#   'expensive',
#   'small',
#   'mix',
#   'pack',
#   'to',
#   'monthly',
#   'pack',
#   'to',
#   'etc',
#   'etc'],
#  ['investing',
#   'in',
#   'building',
#   'champions',
#   'is',
#   'massive',
#   'let',
#   'down',
#   'when',
#   'they',
#   'are',
#   'killed',
#   'by',
#   'rebalancing',
#   'just',
#   'as',
#   'you',
#   'are',
#   'about',
#   'to',
#   'try',
#   'them',
#   'wasted',
#   'resources',
#   'stay',
#   'wasted',
#   'of',
#   'course',
#   'decent',
#   'maxing',
#   'an',
#   'excellent',
#   'champion',
#   'then',
#   'having',
#   'everything',
#   'about',
#   'him',
#   'killed',
#   'then',
#   'told',
#   'he',
#   'is',
#   'still',
#   'decent',
#   'guess',
#   'that',
#   'should',
#   'teach',
#   'me',
#   'to',
#   'not',
#   'use',
#   'resources',
#   'on',
#   'an',
#   'exciting',
#   'addition',
#   'to',
#   'this',
#   'game',
#   'since',
#   'he',
#   'is',
#   'now',
#   'champion',
#   'will',
#   'not',
#   'even',
#   'get',
#   'to',
#   'try'],
#  ['you',
#   'will',
#   'commit',
#   'to',
#   'huge',
#   'amount',
#   'of',
#   'time',
#   'day',
#   'if',
#   'you',
#   'want',
#   'to',
#   'play',
#   'this',
#   'game',
#   'at',
#   'least',
#   'to',
#   'hours',
#   'on',
#   'the',
#   'daily',
#   'grind',
#   'for',
#   'leveling',
#   'silver',
#   'gear',
#   'and',
#   'books',
#   'any',
#   'of',
#   'the',
#   'fun',
#   'stuff',
#   'like',
#   'configuring',
#   'teams',
#   'champs',
#   'will',
#   'cost',
#   'in',
#   'time',
#   'silver',
#   'and',
#   'books',
#   'other',
#   'games',
#   'are',
#   'kinder',
#   'in',
#   'rewards',
#   'tournaments',
#   'events',
#   'and',
#   'qol',
#   'issues',
#   'not',
#   'plarium',
#   'feedback',
#   'and',
#   'suggestions',
#   'will',
#   'almost',
#   'assuredly',
#   'be',
#   'met',
#   'with',
#   'empty',
#   'lip',
#   'service',
#   'or',
#   'ignored',
#   'oh',
#   'and',
#   'you',
#   'll',
#   'find',
#   'out',
#   'soon',
#   'enough',
#   'that',
#   'they',
#   'don',
#   'even',
#   'play',
#   'their',
#   'own',
#   'game'],
#  ['the',
#   'game',
#   'is',
#   'absolutely',
#   'horrible',
#   'frustrating',
#   'how',
#   'is',
#   'it',
#   'even',
#   'logical',
#   'that',
#   'play',
#   'all',
#   'day',
#   'long',
#   'to',
#   'waste',
#   'all',
#   'the',
#   'silver',
#   'on',
#   'upgrading',
#   'item',
#   'from',
#   'level',
#   'to',
#   'what',
#   'waste',
#   'of',
#   'time',
#   'and',
#   'efforts',
#   'don',
#   'recommend',
#   'it',
#   'to',
#   'anyone',
#   'tbh',
#   'horrible',
#   'response',
#   'to',
#   'say',
#   'the',
#   'least',
#   'so',
#   'you',
#   'expect',
#   'me',
#   'to',
#   'play',
#   'for',
#   'couple',
#   'of',
#   'days',
#   'save',
#   'and',
#   'buy',
#   'silver',
#   'to',
#   'end',
#   'up',
#   'wasting',
#   'them',
#   'on',
#   'item',
#   'to',
#   'get',
#   'it',
#   'to',
#   'or',
#   'where',
#   'is',
#   'the',
#   'logic',
#   'here',
#   'how',
#   'about',
#   'you',
#   'make',
#   'the',
#   'upgrade',
#   'cost',
#   'or',
#   'for',
#   'certain',
#   'instead',
#   'of',
#   'wasting',
#   'our',
#   'time'],
#  ['would',
#   'take',
#   'extreme',
#   'caution',
#   'spending',
#   'money',
#   'in',
#   'this',
#   'game',
#   'not',
#   'too',
#   'long',
#   'ago',
#   'they',
#   'had',
#   'an',
#   'event',
#   'to',
#   'open',
#   'ancient',
#   'shards',
#   'which',
#   'are',
#   'not',
#   'cheap',
#   'and',
#   'you',
#   'would',
#   'get',
#   'great',
#   'champion',
#   'just',
#   'today',
#   'they',
#   'nerfed',
#   'that',
#   'same',
#   'champion',
#   'they',
#   'also',
#   'nerfed',
#   'other',
#   'champions',
#   'in',
#   'which',
#   'people',
#   'have',
#   'spent',
#   'money',
#   'to',
#   'obtain',
#   'if',
#   'play',
#   'this',
#   'game',
#   'do',
#   'not',
#   'spend',
#   'money',
#   'because',
#   'you',
#   'may',
#   'get',
#   'something',
#   'great',
#   'to',
#   'help',
#   'you',
#   'only',
#   'for',
#   'this',
#   'company',
#   'to',
#   'pretty',
#   'much',
#   'take',
#   'that',
#   'away',
#   'company',
#   'should',
#   'always',
#   'make',
#   'other',
#   'characters',
#   'as',
#   'good',
#   'instead'],
#  ['it',
#   'little',
#   'better',
#   'but',
#   'the',
#   'rate',
#   'for',
#   'pulls',
#   'is',
#   'still',
#   'disappointing',
#   'wish',
#   'there',
#   'was',
#   'better',
#   'way',
#   'to',
#   'get',
#   'silver',
#   'shards',
#   'and',
#   'books',
#   'it',
#   'would',
#   'be',
#   'awesome',
#   'if',
#   'we',
#   'could',
#   'reroll',
#   'certain',
#   'stats',
#   'on',
#   'artifacts',
#   'and',
#   'accessories',
#   'for',
#   'silver',
#   'events',
#   'arena',
#   'and',
#   'tournaments',
#   'should',
#   'be',
#   'separated',
#   'by',
#   'players',
#   'power',
#   'level',
#   'the',
#   'bosses',
#   'info',
#   'could',
#   'give',
#   'champions',
#   'suggestions',
#   'summon',
#   'shard',
#   'count',
#   'so',
#   'we',
#   'know',
#   'when',
#   'we',
#   'get',
#   'guaranteed',
#   'legends',
#   'and',
#   'epic',
#   'chicken',
#   'and',
#   'silver',
#   'dungeon',
#   'please',
#   'bring',
#   'back',
#   'the',
#   'old',
#   'fusion',
#   'system'],
#  ['graphics',
#   'are',
#   'awesome',
#   'fights',
#   'are',
#   'decent',
#   'stories',
#   'good',
#   'now',
#   'onto',
#   'my',
#   'problem',
#   'with',
#   'this',
#   'game',
#   'strongly',
#   'dislike',
#   'being',
#   'nicked',
#   'and',
#   'diced',
#   'to',
#   'death',
#   'for',
#   'every',
#   'little',
#   'thing',
#   'and',
#   'those',
#   'things',
#   'don',
#   'even',
#   'guarantee',
#   'anything',
#   'except',
#   'that',
#   'it',
#   'will',
#   'cost',
#   'you',
#   'when',
#   'try',
#   'to',
#   'upgrade',
#   'my',
#   'gear',
#   'its',
#   'highway',
#   'robbery',
#   'simple',
#   'upgrade',
#   'should',
#   'not',
#   'end',
#   'up',
#   'costing',
#   'me',
#   'over',
#   'silver',
#   'because',
#   'the',
#   'chance',
#   'upgrade',
#   'failed',
#   'that',
#   'many',
#   'times',
#   'if',
#   'paying',
#   'for',
#   'the',
#   'upgrade',
#   'just',
#   'upgrade',
#   'it'],
#  ['the',
#   'tag',
#   'team',
#   'arena',
#   'is',
#   'as',
#   'big',
#   'mess',
#   'as',
#   'the',
#   'regular',
#   'arena',
#   'used',
#   'to',
#   'be',
#   'the',
#   'game',
#   'totally',
#   'depends',
#   'on',
#   'getting',
#   'the',
#   'right',
#   'champions',
#   'which',
#   'is',
#   'next',
#   'to',
#   'impossible',
#   'getting',
#   'the',
#   'great',
#   'ones',
#   'is',
#   'far',
#   'too',
#   'hard',
#   'you',
#   'receive',
#   'way',
#   'too',
#   'many',
#   'useless',
#   'duplicate',
#   'champions',
#   'their',
#   'customer',
#   'service',
#   'sucks',
#   'upgrading',
#   'artifacts',
#   'becomes',
#   'next',
#   'to',
#   'impossible',
#   'and',
#   'it',
#   'boring',
#   'and',
#   'takes',
#   'too',
#   'long',
#   'to',
#   'get',
#   'enough',
#   'money',
#   'the',
#   'milestones',
#   'in',
#   'the',
#   'tournaments',
#   'are',
#   'ridiculously',
#   'high',
#   'and',
#   'the',
#   'rewards',
#   'are',
#   'pathetic',
#   'everything',
#   'is',
#   'so',
#   'expensive'],
#  ['like',
#   'the',
#   'game',
#   'and',
#   'really',
#   'enjoy',
#   'it',
#   'despite',
#   'the',
#   'obvious',
#   'cash',
#   'grab',
#   'complaints',
#   'everyone',
#   'makes',
#   'completely',
#   'and',
#   'do',
#   'very',
#   'well',
#   'by',
#   'comparison',
#   'to',
#   'others',
#   'at',
#   'my',
#   'level',
#   'by',
#   'careful',
#   'investment',
#   'strategical',
#   'progression',
#   'and',
#   'patience',
#   'it',
#   'not',
#   'impossible',
#   'to',
#   'just',
#   'slow',
#   'worth',
#   'playing',
#   'just',
#   'don',
#   'expect',
#   'to',
#   'progress',
#   'quickly',
#   'without',
#   'forking',
#   'over',
#   'the',
#   'cash',
#   'besides',
#   'see',
#   'all',
#   'the',
#   'advertising',
#   'they',
#   'do',
#   'that',
#   'why',
#   'it',
#   'costs',
#   'so',
#   'much'],
#  ['need',
#   'to',
#   'update',
#   'rating',
#   'after',
#   'another',
#   'year',
#   'of',
#   'playing',
#   'new',
#   'players',
#   'will',
#   'save',
#   'your',
#   'time',
#   'don',
#   'play',
#   'this',
#   'game',
#   'cause',
#   'nothing',
#   'in',
#   'this',
#   'game',
#   'is',
#   'certain',
#   'except',
#   'only',
#   'one',
#   'thing',
#   'the',
#   'customer',
#   'is',
#   'the',
#   'very',
#   'least',
#   'thing',
#   'they',
#   'care',
#   'about',
#   'also',
#   'they',
#   'are',
#   'very',
#   'predatory',
#   'and',
#   'postpone',
#   'their',
#   'promises',
#   'they',
#   'often',
#   'lies',
#   'and',
#   'never',
#   'explain',
#   'why',
#   'they',
#   'did',
#   'it',
#   'the',
#   'way',
#   'they',
#   'did',
#   'they',
#   'often',
#   'say',
#   'it',
#   'part',
#   'of',
#   'bigger',
#   'picture',
#   'which',
#   'they',
#   'never',
#   'bother',
#   'to',
#   'share',
#   'ever',
#   'they',
#   'run',
#   'the',
#   'game',
#   'as',
#   'casino',
#   'you',
#   'never',
#   'win'],
#  ['there',
#   'is',
#   'bunch',
#   'of',
#   'glitches',
#   'you',
#   'do',
#   'challenges',
#   'and',
#   'you',
#   'don',
#   'get',
#   'credit',
#   'for',
#   'them',
#   'but',
#   'the',
#   'biggest',
#   'thing',
#   'think',
#   'is',
#   'that',
#   'people',
#   'that',
#   'have',
#   'stopped',
#   'playing',
#   'stay',
#   'in',
#   'the',
#   'game',
#   'against',
#   'you',
#   'when',
#   'you',
#   'fight',
#   'in',
#   'the',
#   'arena',
#   'all',
#   'you',
#   'get',
#   'are',
#   'people',
#   'or',
#   'groups',
#   'that',
#   'can',
#   'be',
#   'you',
#   'and',
#   'are',
#   'way',
#   'higher',
#   'than',
#   'you',
#   'that',
#   'not',
#   'fair',
#   'you',
#   'should',
#   'be',
#   'challenging',
#   'people',
#   'that',
#   'are',
#   'around',
#   'your',
#   'same',
#   'level',
#   'regardless',
#   'of',
#   'how',
#   'far',
#   'down',
#   'they',
#   'have',
#   'dropped',
#   'in',
#   'the',
#   'rankings',
#   'because',
#   'they',
#   're',
#   'no',
#   'longer',
#   'playing'],
#  ['by',
#   'far',
#   'the',
#   'most',
#   'enjoyable',
#   'game',
#   'ive',
#   'played',
#   'on',
#   'mobile',
#   'devices',
#   'im',
#   'playing',
#   'ftp',
#   'and',
#   'have',
#   'zero',
#   'complaints',
#   'love',
#   'upgrading',
#   'my',
#   'champs',
#   'and',
#   'getting',
#   'them',
#   'stronger',
#   'daily',
#   'how',
#   'come',
#   'nobody',
#   'mentions',
#   'the',
#   'fact',
#   'there',
#   'is',
#   'no',
#   'ads',
#   'in',
#   'this',
#   'game',
#   'sure',
#   'there',
#   'are',
#   'the',
#   'opening',
#   'offers',
#   'to',
#   'purchase',
#   'in',
#   'game',
#   'materials',
#   'but',
#   'other',
#   'ads',
#   'ill',
#   'definitely',
#   'keep',
#   'playing',
#   'this',
#   'game',
#   'and',
#   'recommend',
#   'it',
#   'to',
#   'everyone'],
#  ['give',
#   'it',
#   'star',
#   'still',
#   'have',
#   'ninja',
#   'as',
#   'character',
#   'none',
#   'of',
#   'the',
#   'characters',
#   'have',
#   'true',
#   'amount',
#   'of',
#   'detail',
#   'pvp',
#   'is',
#   'garbage',
#   'and',
#   'progression',
#   'is',
#   'so',
#   'slow',
#   'turtle',
#   'could',
#   'sit',
#   'and',
#   'play',
#   'comfortably',
#   'all',
#   'and',
#   'all',
#   'you',
#   'can',
#   'tell',
#   'all',
#   'the',
#   'money',
#   'is',
#   'in',
#   'the',
#   'ads',
#   'instead',
#   'of',
#   'the',
#   'actual',
#   'game',
#   'it',
#   'nowhere',
#   'near',
#   'as',
#   'fun',
#   'as',
#   'they',
#   'make',
#   'it',
#   'seem',
#   'and',
#   'frankly',
#   'cleared',
#   'it',
#   'for',
#   'the',
#   'space',
#   'for',
#   'something',
#   'actually',
#   'fun',
#   'sad'],
#  ['game',
#   'was',
#   'great',
#   'parts',
#   'still',
#   'are',
#   'game',
#   'gets',
#   'stars',
#   'for',
#   'gameplay',
#   'but',
#   'resounding',
#   'zero',
#   'for',
#   'customer',
#   'support',
#   'also',
#   'offered',
#   'an',
#   'event',
#   'to',
#   'receive',
#   'champion',
#   'which',
#   'people',
#   'paid',
#   'for',
#   'and',
#   'then',
#   'changed',
#   'the',
#   'champion',
#   'after',
#   'to',
#   'the',
#   'point',
#   'he',
#   'is',
#   'barely',
#   'usable',
#   'very',
#   'shady',
#   'business',
#   'practices',
#   'by',
#   'developer',
#   'that',
#   'does',
#   'not',
#   'care',
#   'about',
#   'its',
#   'community'],
#  ['have',
#   'been',
#   'playing',
#   'for',
#   'over',
#   'year',
#   'and',
#   'while',
#   'the',
#   'game',
#   'is',
#   'fun',
#   'it',
#   'impossible',
#   'to',
#   'progress',
#   'without',
#   'spending',
#   'serious',
#   'money',
#   'very',
#   'expensive',
#   'not',
#   'free',
#   'to',
#   'play',
#   'friendly',
#   'worth',
#   'download',
#   'but',
#   'expect',
#   'to',
#   'never',
#   'compete',
#   'later',
#   'in',
#   'the',
#   'game',
#   'unless',
#   'you',
#   'drop',
#   'lot',
#   'of',
#   'money',
#   'update',
#   'game',
#   'has',
#   'gotten',
#   'worse',
#   'plarium',
#   'is',
#   'constantly',
#   'adding',
#   'players',
#   'and',
#   'different',
#   'aspects',
#   'to',
#   'the',
#   'game',
#   'so',
#   'get',
#   'you',
#   'to',
#   'spend',
#   'that',
#   'the',
#   'only',
#   'way',
#   'to',
#   'advance',
#   'don',
#   'waste',
#   'your',
#   'time'],
#  ['game',
#   'crashes',
#   'constantly',
#   'during',
#   'battles',
#   'the',
#   'last',
#   'update',
#   'addresses',
#   'the',
#   'pop',
#   'ups',
#   'which',
#   'is',
#   'actually',
#   'much',
#   'more',
#   'tolerable',
#   'the',
#   'gameplay',
#   'is',
#   'great',
#   'the',
#   'graphics',
#   'are',
#   'great',
#   'but',
#   'learning',
#   'to',
#   'set',
#   'each',
#   'character',
#   'with',
#   'the',
#   'right',
#   'setup',
#   'is',
#   'challenging',
#   'the',
#   'only',
#   'issue',
#   'right',
#   'now',
#   'is',
#   'that',
#   'the',
#   'game',
#   'is',
#   'crashing',
#   'mid',
#   'battles',
#   'and',
#   'frequently',
#   'haven',
#   'played',
#   'the',
#   'game',
#   'in',
#   'days',
#   'because',
#   'of',
#   'it'],
#  ['game',
#   'would',
#   'be',
#   'awesome',
#   'if',
#   'you',
#   'didn',
#   'get',
#   'pounded',
#   'by',
#   'the',
#   'buy',
#   'this',
#   'pop',
#   'ups',
#   'they',
#   'hit',
#   'you',
#   'with',
#   'constantly',
#   'oh',
#   'and',
#   'the',
#   'shards',
#   'that',
#   'turn',
#   'into',
#   'heros',
#   'are',
#   'awful',
#   'rates',
#   'played',
#   'for',
#   'months',
#   'gathering',
#   'all',
#   'the',
#   'free',
#   'purple',
#   'and',
#   'gold',
#   'shards',
#   'had',
#   'other',
#   'people',
#   'play',
#   'for',
#   'months',
#   'to',
#   'get',
#   'those',
#   'shards',
#   'too',
#   'and',
#   'used',
#   'them',
#   'during',
#   'boosted',
#   'portal',
#   'had',
#   'gold',
#   'purple',
#   'got',
#   'gold',
#   'hero',
#   'from',
#   'the',
#   'golds',
#   'and',
#   'like',
#   'purple',
#   'heros',
#   'from',
#   'the',
#   'purples',
#   'they',
#   'all',
#   'opened',
#   'down',
#   'and',
#   'have',
#   'to',
#   'be',
#   'spent',
#   'to',
#   'advance'],
#  ['it',
#   'is',
#   'without',
#   'doubt',
#   'long',
#   'haul',
#   'game',
#   'don',
#   'expect',
#   'to',
#   'rush',
#   'this',
#   'content',
#   'the',
#   'draw',
#   'for',
#   'me',
#   'is',
#   'the',
#   'myriad',
#   'systems',
#   'that',
#   'you',
#   'can',
#   'invest',
#   'in',
#   'to',
#   'strengthen',
#   'your',
#   'champions',
#   'and',
#   'the',
#   'interplay',
#   'amongst',
#   'them',
#   'the',
#   'details',
#   'of',
#   'the',
#   'gear',
#   'team',
#   'composition',
#   'visual',
#   'variety',
#   'and',
#   'content',
#   'specialists',
#   'create',
#   'an',
#   'atmosphere',
#   'where',
#   'there',
#   'isn',
#   'one',
#   'size',
#   'fits',
#   'all',
#   'for',
#   'any',
#   'of',
#   'the',
#   'above',
#   'which',
#   'in',
#   'turn',
#   'keeps',
#   'things',
#   'fresh',
#   'important',
#   'note',
#   'for',
#   'beginners',
#   'stay',
#   'focused',
#   'on',
#   'core',
#   'team',
#   'of',
#   'champions',
#   'resources',
#   'are',
#   'limited'],
#  ['this',
#   'game',
#   'is',
#   'fun',
#   'but',
#   'overpriced',
#   'and',
#   'designed',
#   'to',
#   'force',
#   'players',
#   'to',
#   'buy',
#   'packs',
#   'to',
#   'progress',
#   'they',
#   'do',
#   'have',
#   'ways',
#   'to',
#   'earn',
#   'gems',
#   'and',
#   'shards',
#   'but',
#   'it',
#   'can',
#   'be',
#   'long',
#   'tedious',
#   'process',
#   'like',
#   'most',
#   'pay',
#   'to',
#   'win',
#   'games',
#   'are',
#   'the',
#   'packs',
#   'are',
#   'very',
#   'overpriced',
#   'and',
#   'pay',
#   'to',
#   'win',
#   'players',
#   'are',
#   'probably',
#   'forking',
#   'over',
#   'cash',
#   'hand',
#   'over',
#   'fist',
#   'to',
#   'get',
#   'ahead',
#   'have',
#   'bought',
#   'pack',
#   'before',
#   'but',
#   'can',
#   'fathom',
#   'the',
#   'idea',
#   'of',
#   'spending',
#   'that',
#   'much',
#   'money',
#   'on',
#   'mobile',
#   'game',
#   'my',
#   'advice',
#   'is',
#   'play',
#   'but',
#   'don',
#   'spend',
#   'your',
#   'money'],
#  ['have',
#   'been',
#   'playing',
#   'this',
#   'game',
#   'since',
#   'beta',
#   'and',
#   'have',
#   'level',
#   'account',
#   'let',
#   'be',
#   'very',
#   'clear',
#   'plarium',
#   'have',
#   'nothing',
#   'but',
#   'contemp',
#   'for',
#   'the',
#   'player',
#   'base',
#   'not',
#   'just',
#   'greed',
#   'though',
#   'their',
#   'cynical',
#   'exploitation',
#   'of',
#   'players',
#   'is',
#   'breathtaking',
#   'no',
#   'am',
#   'talking',
#   'about',
#   'fundamental',
#   'disregard',
#   'about',
#   'the',
#   'people',
#   'who',
#   'have',
#   'invested',
#   'not',
#   'just',
#   'money',
#   'but',
#   'huge',
#   'amount',
#   'of',
#   'time',
#   'into',
#   'this',
#   'game',
#   'only',
#   'play',
#   'raid',
#   'because',
#   'of',
#   'the',
#   'people',
#   'otherwise',
#   'would',
#   'walk',
#   'away',
#   'strongly',
#   'urge',
#   'anyone',
#   'thinking',
#   'of',
#   'picking',
#   'up',
#   'this',
#   'game',
#   'don'],
#  ['simply',
#   'because',
#   'extra',
#   'transactions',
#   'will',
#   'sneak',
#   'up',
#   'if',
#   'you',
#   'ain',
#   'careful',
#   'decided',
#   'to',
#   'give',
#   'it',
#   'shot',
#   'and',
#   'purchase',
#   'the',
#   'silver',
#   'raid',
#   'pass',
#   'month',
#   'card',
#   'and',
#   'the',
#   'system',
#   'doesn',
#   'really',
#   'make',
#   'it',
#   'aware',
#   'to',
#   'you',
#   'that',
#   'it',
#   'automatically',
#   'setting',
#   'it',
#   'up',
#   'for',
#   'auto',
#   'renewal',
#   'because',
#   'the',
#   'option',
#   'beforehand',
#   'isn',
#   'given',
#   'it',
#   'only',
#   'in',
#   'fine',
#   'print',
#   'at',
#   'the',
#   'bottom',
#   'which',
#   'is',
#   'obviously',
#   'sneaky',
#   'on',
#   'purpose',
#   'to',
#   'get',
#   'more',
#   'money',
#   've',
#   'been',
#   'charged',
#   'for',
#   'few',
#   'months',
#   'now',
#   'without',
#   'being',
#   'aware',
#   'hoping',
#   'to',
#   'atleast',
#   'get',
#   'reimbursed',
#   'this',
#   'last',
#   'payment'],
#  ['this',
#   'game',
#   'is',
#   'money',
#   'pit',
#   'save',
#   'your',
#   'time',
#   'and',
#   'money',
#   'in',
#   'order',
#   'to',
#   'compete',
#   'you',
#   'need',
#   'to',
#   'spend',
#   'money',
#   'lots',
#   'of',
#   'money',
#   'the',
#   'packs',
#   'they',
#   'sell',
#   'in',
#   'the',
#   'game',
#   'are',
#   'way',
#   'to',
#   'expensive',
#   'the',
#   'arena',
#   'is',
#   'awful',
#   'part',
#   'of',
#   'the',
#   'game',
#   'it',
#   'will',
#   'get',
#   'boring',
#   'quickly',
#   'from',
#   'the',
#   'match',
#   'ups',
#   'you',
#   'get',
#   'if',
#   'you',
#   'want',
#   'game',
#   'full',
#   'of',
#   'disappointments',
#   'this',
#   'is',
#   'your',
#   'game',
#   'game',
#   'has',
#   'so',
#   'many',
#   'glitchs',
#   'game',
#   'is',
#   'allegedly',
#   'owned',
#   'by',
#   'casino',
#   'need',
#   'say',
#   'more',
#   'the',
#   'support',
#   'is',
#   'awful',
#   'same',
#   'vanilla',
#   'response',
#   'they',
#   'try',
#   'to',
#   'force',
#   'you',
#   'to',
#   'spend',
#   'to',
#   'advance',
#   'in',
#   'the',
#   'game'],
#  ['game',
#   'in',
#   'general',
#   'has',
#   'been',
#   'more',
#   'buggy',
#   'lately',
#   'have',
#   'an',
#   'so',
#   'my',
#   'device',
#   'is',
#   'up',
#   'to',
#   'par',
#   'regretfully',
#   'have',
#   'spent',
#   'money',
#   'on',
#   'it',
#   'and',
#   'once',
#   'you',
#   'do',
#   'they',
#   'actually',
#   'offer',
#   'you',
#   'more',
#   'ways',
#   'to',
#   'spend',
#   'money',
#   'the',
#   'gameplay',
#   'is',
#   'simple',
#   'and',
#   'complex',
#   'turn',
#   'based',
#   'strategy',
#   'graphics',
#   'are',
#   'great',
#   'for',
#   'the',
#   'most',
#   'part',
#   'too',
#   'much',
#   'gacha',
#   'for',
#   'to',
#   'usd',
#   'you',
#   'could',
#   'get',
#   'full',
#   'game',
#   'with',
#   'excellent',
#   'content',
#   'that',
#   'might',
#   'give',
#   'you',
#   'low',
#   'chance',
#   'for',
#   'good',
#   'characters',
#   'so',
#   'waste',
#   'of',
#   'money',
#   'typically'],
#  ['the',
#   'game',
#   'itself',
#   'is',
#   'absolutely',
#   'brilliant',
#   'very',
#   'time',
#   'consuming',
#   'and',
#   'repetitive',
#   'at',
#   'times',
#   'what',
#   'more',
#   'frustrating',
#   'is',
#   'how',
#   'plarium',
#   'treats',
#   'the',
#   'player',
#   'base',
#   'with',
#   'dispise',
#   'in',
#   'the',
#   'latest',
#   'move',
#   'taking',
#   'away',
#   'free',
#   'chickens',
#   'and',
#   'shards',
#   'not',
#   'even',
#   'starting',
#   'the',
#   'topics',
#   'of',
#   'constant',
#   'lack',
#   'of',
#   'silver',
#   'lack',
#   'of',
#   'books',
#   'edit',
#   'taking',
#   'away',
#   'the',
#   'sacred',
#   'after',
#   'playing',
#   'for',
#   'so',
#   'long',
#   'is',
#   'still',
#   'an',
#   'evil',
#   'move',
#   'gets',
#   'fat',
#   'thumb',
#   'down',
#   'and',
#   'don',
#   'get',
#   'me',
#   'started',
#   'on',
#   'dt',
#   'bosses',
#   'our',
#   'whole',
#   'clan',
#   'is',
#   'stuck',
#   'on',
#   'bommal',
#   'has',
#   'given',
#   'up',
#   'on',
#   'this',
#   'round'],
#  ['have',
#   'been',
#   'playing',
#   'this',
#   'game',
#   'for',
#   'long',
#   'time',
#   'and',
#   'have',
#   'spent',
#   'over',
#   'in',
#   'the',
#   'last',
#   'couple',
#   'of',
#   'years',
#   'on',
#   'it',
#   'but',
#   'am',
#   'done',
#   'now',
#   'what',
#   'an',
#   'incompetent',
#   'company',
#   'it',
#   'takes',
#   'forever',
#   'to',
#   'get',
#   'through',
#   'the',
#   'content',
#   'and',
#   'instead',
#   'of',
#   'making',
#   'it',
#   'faster',
#   'they',
#   'make',
#   'more',
#   'content',
#   'to',
#   'do',
#   'slowly',
#   'that',
#   'not',
#   'even',
#   'getting',
#   'into',
#   'the',
#   'amount',
#   'of',
#   'time',
#   'and',
#   'or',
#   'money',
#   'you',
#   'put',
#   'into',
#   'the',
#   'champions',
#   'to',
#   'have',
#   'them',
#   'nerfed',
#   'and',
#   'they',
#   'don',
#   'even',
#   'give',
#   'you',
#   'anything',
#   'back',
#   've',
#   'just',
#   'had',
#   'it',
#   'everyone',
#   'saying',
#   'it',
#   'going',
#   'to',
#   'get',
#   'better',
#   'but',
#   'it',
#   'gets',
#   'worse'],
#  ['patience',
#   'is',
#   'the',
#   'key',
#   'was',
#   'able',
#   'to',
#   'get',
#   'legendaries',
#   'via',
#   'log',
#   'in',
#   'rewards',
#   'and',
#   'collecting',
#   'shards',
#   'that',
#   'luckily',
#   'pulled',
#   'out',
#   'legendary',
#   'characters',
#   'just',
#   'lucky',
#   'and',
#   'patient',
#   'guess',
#   'been',
#   'playing',
#   'for',
#   'years',
#   'now',
#   'and',
#   'even',
#   'my',
#   'characters',
#   'are',
#   'strong',
#   'just',
#   'upgrade',
#   'all',
#   'the',
#   'armors',
#   'and',
#   'items',
#   'like',
#   'ring',
#   'necklace',
#   'and',
#   'banner',
#   'and',
#   'do',
#   'scroll',
#   'masteries',
#   'too',
#   'never',
#   'spent',
#   'money',
#   'just',
#   'patient',
#   'man'],
#  ['the',
#   'game',
#   'is',
#   'very',
#   'fun',
#   'in',
#   'the',
#   'beginning',
#   'but',
#   'after',
#   'playing',
#   'for',
#   'very',
#   'long',
#   'time',
#   'it',
#   'becomes',
#   'evident',
#   'that',
#   'the',
#   'end',
#   'game',
#   'is',
#   'abusive',
#   'they',
#   'began',
#   'holding',
#   'events',
#   'for',
#   'powerful',
#   'champions',
#   'encouraging',
#   'you',
#   'to',
#   'spend',
#   'money',
#   'on',
#   'them',
#   'then',
#   'they',
#   'would',
#   'nerf',
#   'the',
#   'champion',
#   'to',
#   'either',
#   'something',
#   'much',
#   'less',
#   'useful',
#   'or',
#   'not',
#   'useful',
#   'at',
#   'all'],
#  ['got',
#   'past',
#   'the',
#   'lack',
#   'of',
#   'energy',
#   'phase',
#   'got',
#   'pretty',
#   'good',
#   'selection',
#   'of',
#   'champs',
#   'now',
#   'lots',
#   'of',
#   'things',
#   'to',
#   'do',
#   'until',
#   'hit',
#   'wall',
#   'with',
#   'the',
#   'changes',
#   'they',
#   'did',
#   'to',
#   'arena',
#   'stupid',
#   'missions',
#   'are',
#   'tied',
#   'up',
#   'to',
#   'farm',
#   'medals',
#   'in',
#   'the',
#   'dreaded',
#   'arena',
#   'place',
#   'where',
#   'face',
#   'opponents',
#   'of',
#   'my',
#   'skill',
#   'level',
#   'which',
#   'can',
#   'whipe',
#   'any',
#   'of',
#   'my',
#   'strongest',
#   'champs',
#   'without',
#   'even',
#   'taking',
#   'turn',
#   'trying',
#   'to',
#   'find',
#   'an',
#   'efficient',
#   'team',
#   'when',
#   'you',
#   'have',
#   'limited',
#   'turns',
#   'and',
#   'have',
#   'to',
#   'spend',
#   'days',
#   'to',
#   'gear',
#   'up',
#   'new',
#   'champ',
#   'is',
#   'ridiculous',
#   'even',
#   'more',
#   'when',
#   'next',
#   'missions',
#   'are',
#   'easy'],
#  ['wouldn',
#   'bother',
#   'playing',
#   'looks',
#   'great',
#   'but',
#   'they',
#   'aggressively',
#   'want',
#   'you',
#   'to',
#   'spend',
#   'in',
#   'this',
#   'game',
#   'and',
#   'then',
#   'nerf',
#   'champions',
#   'months',
#   'later',
#   'into',
#   'the',
#   'ground',
#   'urogrim',
#   'and',
#   'also',
#   'geomancer',
#   'can',
#   'recommend',
#   'considering',
#   'they',
#   'won',
#   'even',
#   'offer',
#   'you',
#   'the',
#   'option',
#   'to',
#   'refund',
#   'the',
#   'resources',
#   'you',
#   'spent',
#   'on',
#   'the',
#   'nerves',
#   'champion',
#   'keep',
#   'in',
#   'mind',
#   'they',
#   'play',
#   'test',
#   'before',
#   'release',
#   'and',
#   'also',
#   'have',
#   'cc',
#   'playing',
#   'on',
#   'test',
#   'server',
#   'offering',
#   'feedback',
#   'so',
#   'there',
#   'no',
#   'excuse',
#   'for',
#   'plarium'],
#  ['got',
#   'up',
#   'to',
#   'level',
#   'was',
#   'casually',
#   'upgrading',
#   'heroes',
#   'and',
#   'completing',
#   'quests',
#   'doing',
#   'really',
#   'well',
#   'liked',
#   'the',
#   'game',
#   'and',
#   'was',
#   'enjoying',
#   'my',
#   'time',
#   'but',
#   'then',
#   'then',
#   'saw',
#   'that',
#   'could',
#   'log',
#   'in',
#   'with',
#   'facebook',
#   'to',
#   'keep',
#   'my',
#   'progress',
#   'saved',
#   'great',
#   'idea',
#   'right',
#   'nope',
#   'an',
#   'hour',
#   'of',
#   'progress',
#   'down',
#   'the',
#   'drain',
#   'the',
#   'game',
#   'reset',
#   'entirely',
#   'and',
#   'lost',
#   'everything',
#   'lost',
#   'it',
#   'all',
#   'why',
#   'trying',
#   'to',
#   'ensure',
#   'didnt',
#   'well',
#   'lose',
#   'it',
#   'all',
#   'what',
#   'joke'],
#  ['it',
#   'nice',
#   'dungeon',
#   'crawl',
#   'there',
#   'are',
#   'few',
#   'things',
#   'that',
#   'could',
#   'make',
#   'it',
#   'instantly',
#   'better',
#   'books',
#   'are',
#   'one',
#   'of',
#   'the',
#   'hardest',
#   'things',
#   'to',
#   'come',
#   'by',
#   'in',
#   'the',
#   'game',
#   'it',
#   'will',
#   'make',
#   'game',
#   'play',
#   'so',
#   'much',
#   'better',
#   'if',
#   'there',
#   'were',
#   'champ',
#   'reset',
#   'option',
#   'to',
#   'recover',
#   'mats',
#   'at',
#   'the',
#   'coast',
#   'of',
#   'gems',
#   'that',
#   'would',
#   'solve',
#   'so',
#   'many',
#   'problems',
#   'in',
#   'the',
#   'community'],
#  ['honestly',
#   'the',
#   'game',
#   'is',
#   'beautiful',
#   'but',
#   'it',
#   'doesn',
#   'just',
#   'define',
#   'the',
#   'word',
#   'grind',
#   'it',
#   'abuses',
#   'it',
#   'this',
#   'is',
#   'an',
#   'extremely',
#   'repetitive',
#   'game',
#   'at',
#   'the',
#   'same',
#   'time',
#   'you',
#   'are',
#   'dodging',
#   'ads',
#   'everytime',
#   'you',
#   'load',
#   'up',
#   'you',
#   'feel',
#   'stuck',
#   'at',
#   'certain',
#   'point',
#   'and',
#   'becomes',
#   'no',
#   'fun',
#   'uninstalled',
#   'this',
#   'since',
#   'you',
#   'will',
#   'be',
#   'forced',
#   'to',
#   'ask',
#   'yourself',
#   'if',
#   'you',
#   'should',
#   'be',
#   'spending',
#   'money',
#   'or',
#   'more',
#   'time',
#   'just',
#   'forget',
#   'it',
#   'because',
#   'you',
#   'don',
#   'feel',
#   'like',
#   'you',
#   'are',
#   'winning',
#   'even',
#   'when',
#   'you',
#   'do'],
#  ['game',
#   'is',
#   'good',
#   'but',
#   'real',
#   'review',
#   'to',
#   'start',
#   'how',
#   'about',
#   'farming',
#   'potions',
#   'with',
#   'what',
#   'energy',
#   'you',
#   'do',
#   'have',
#   'and',
#   'pow',
#   'you',
#   'are',
#   'rewarded',
#   'with',
#   'xp',
#   'beers',
#   'or',
#   'green',
#   'crystals',
#   'how',
#   'about',
#   'upgrading',
#   'gear',
#   'as',
#   'human',
#   'being',
#   'find',
#   'it',
#   'quite',
#   'disconcerting',
#   'to',
#   'pay',
#   'for',
#   'anything',
#   'don',
#   'receive',
#   'yet',
#   'single',
#   'level',
#   'in',
#   'upgrade',
#   'can',
#   'cost',
#   'us',
#   'upwards',
#   'of',
#   'million',
#   'silver',
#   'get',
#   'that',
#   'it',
#   'has',
#   'success',
#   'rate',
#   'but',
#   'why',
#   'pay',
#   'for',
#   'failure',
#   'gameplay',
#   'stars',
#   'even',
#   'champion',
#   'odds',
#   'stars',
#   'champion',
#   'events',
#   'seems',
#   'midgame',
#   'players',
#   'have',
#   'zero',
#   'chance'],
#  ['this',
#   'game',
#   'is',
#   'the',
#   'very',
#   'worst',
#   'of',
#   'repetitive',
#   'pay',
#   'to',
#   'win',
#   'garbage',
#   'it',
#   'also',
#   'has',
#   'broken',
#   'arena',
#   'system',
#   'which',
#   'is',
#   'incredibly',
#   'dumb',
#   'consider',
#   'this',
#   'game',
#   'waste',
#   'of',
#   'time',
#   'and',
#   'money',
#   'after',
#   'reading',
#   'the',
#   'developers',
#   'response',
#   'feel',
#   'compelled',
#   'to',
#   'add',
#   'that',
#   'the',
#   'developers',
#   'ignore',
#   'the',
#   'players',
#   'feedback',
#   'and',
#   'insist',
#   'their',
#   'broken',
#   'system',
#   'is',
#   'fine',
#   'hint',
#   'it',
#   'not',
#   'they',
#   'also',
#   'nerf',
#   'characters',
#   'after',
#   'you',
#   'invest',
#   'in',
#   'them',
#   'and',
#   'don',
#   'return',
#   'the',
#   'resources',
#   'you',
#   'spent',
#   'to',
#   'build',
#   'them',
#   'feels',
#   'like',
#   'theft',
#   'hate',
#   'this',
#   'game',
#   'avoid'],
#  ['in',
#   'game',
#   'ads',
#   'and',
#   'overly',
#   'complicated',
#   'have',
#   'played',
#   'this',
#   'game',
#   'for',
#   'while',
#   'now',
#   'and',
#   'it',
#   'always',
#   'has',
#   'multiple',
#   'in',
#   'game',
#   'ads',
#   'that',
#   'you',
#   'have',
#   'to',
#   'sift',
#   'through',
#   'before',
#   'you',
#   'can',
#   'begin',
#   'to',
#   'play',
#   'you',
#   'are',
#   'given',
#   'limited',
#   'space',
#   'to',
#   'expand',
#   'your',
#   'character',
#   'choices',
#   'those',
#   'characters',
#   'then',
#   'are',
#   'limited',
#   'to',
#   'how',
#   'far',
#   'you',
#   'can',
#   'upgrade',
#   'it',
#   'is',
#   'basically',
#   'rock',
#   'paper',
#   'scissors',
#   'style',
#   'game',
#   'inorder',
#   'to',
#   'gain',
#   'high',
#   'level',
#   'characters',
#   'you',
#   'have',
#   'to',
#   'sacrifice',
#   'your',
#   'others',
#   'but',
#   'yet',
#   'it',
#   'prevents',
#   'or',
#   'warns',
#   'you',
#   'against',
#   'this'],
#  ['ok',
#   'paying',
#   'bit',
#   'for',
#   'game',
#   'enjoying',
#   'but',
#   'this',
#   'game',
#   'is',
#   'just',
#   'such',
#   'drag',
#   'the',
#   'gameplay',
#   'seems',
#   'deliberately',
#   'slow',
#   'to',
#   'force',
#   'you',
#   'to',
#   'pay',
#   'and',
#   'they',
#   'keep',
#   'shoving',
#   'ada',
#   'for',
#   'their',
#   'sales',
#   'and',
#   'things',
#   'giving',
#   'you',
#   'barely',
#   'enough',
#   'to',
#   'keep',
#   'your',
#   'team',
#   'going',
#   'and',
#   'then',
#   'even',
#   'if',
#   'you',
#   'do',
#   'get',
#   'the',
#   'champion',
#   'equipment',
#   'you',
#   'want',
#   'you',
#   'still',
#   'need',
#   'to',
#   'grind',
#   'pay',
#   'to',
#   'upgrade',
#   'and',
#   'use',
#   'it',
#   'and',
#   'it',
#   'might',
#   'suck',
#   'there',
#   'hundred',
#   'and',
#   'one',
#   'levers',
#   'to',
#   'pull',
#   'but',
#   'you',
#   'need',
#   'to',
#   'grease',
#   'any',
#   'of',
#   'them',
#   'with',
#   'cash',
#   'give',
#   'this',
#   'if',
#   'could'],
#  ['the',
#   'game',
#   'is',
#   'good',
#   'and',
#   'the',
#   'graphics',
#   'are',
#   'great',
#   'but',
#   'to',
#   'be',
#   'honest',
#   'it',
#   'll',
#   'probably',
#   'take',
#   'yrs',
#   'to',
#   'even',
#   'get',
#   'close',
#   'to',
#   'finishing',
#   'the',
#   'amount',
#   'of',
#   'time',
#   'it',
#   'takes',
#   'to',
#   'upgrade',
#   'each',
#   'player',
#   'and',
#   'there',
#   'artifacts',
#   'is',
#   'horrendous',
#   'time',
#   'and',
#   'effort',
#   'is',
#   'not',
#   'the',
#   'problem',
#   'you',
#   'can',
#   'spend',
#   'hours',
#   'day',
#   'on',
#   'this',
#   'game',
#   'for',
#   'whole',
#   'week',
#   'upgrading',
#   'on',
#   'one',
#   'artifact',
#   'to',
#   'level',
#   'it',
#   'impossible',
#   'seriously',
#   'unless',
#   'you',
#   're',
#   'spending',
#   'over',
#   'week',
#   'you',
#   'will',
#   'not',
#   'any',
#   'progression'],
#  ['would',
#   'love',
#   'to',
#   'give',
#   'stars',
#   'but',
#   'can',
#   'this',
#   'game',
#   'has',
#   'become',
#   'absolutely',
#   'terrible',
#   'to',
#   'play',
#   'even',
#   'when',
#   'you',
#   'put',
#   'in',
#   'cash',
#   'to',
#   'try',
#   'progress',
#   'it',
#   'just',
#   'seems',
#   'to',
#   'keep',
#   'disappointing',
#   'you',
#   'in',
#   'every',
#   'way',
#   'possible',
#   'epic',
#   'shards',
#   'are',
#   'exactly',
#   'the',
#   'same',
#   'as',
#   'rare',
#   'ones',
#   'which',
#   'is',
#   'pointless',
#   'game',
#   'is',
#   'fun',
#   'at',
#   'the',
#   'start',
#   'but',
#   'there',
#   'is',
#   'no',
#   'point',
#   'by',
#   'playing',
#   'unless',
#   'you',
#   'have',
#   'deep',
#   'pockets',
#   'past',
#   'level'],
#  ['not',
#   'much',
#   'has',
#   'changed',
#   'drops',
#   'rates',
#   'lg',
#   'potions',
#   'still',
#   'atrocious',
#   'not',
#   'exaggerating',
#   'when',
#   'ran',
#   'dungeon',
#   'and',
#   'didn',
#   'get',
#   'drop',
#   'the',
#   'encouraging',
#   'drop',
#   'rate',
#   'for',
#   'summons',
#   'is',
#   'joke',
#   'purple',
#   'crystals',
#   'should',
#   'not',
#   'spit',
#   'out',
#   'rares',
#   'but',
#   'they',
#   'do',
#   'every',
#   'time',
#   'the',
#   'arena',
#   'power',
#   'system',
#   'is',
#   'still',
#   'garbage',
#   'got',
#   'wiped',
#   'by',
#   'yesterday',
#   'when',
#   'outmatched',
#   'that',
#   'team',
#   'by',
#   'significant',
#   'number',
#   'so',
#   'what',
#   'the',
#   'point',
#   'of',
#   'leveling',
#   'and',
#   'ascending',
#   'leveling',
#   'equipment',
#   'is',
#   'an',
#   'even',
#   'bigger',
#   'joke',
#   'need',
#   'billions',
#   'worth',
#   'in',
#   'silver'],
#  ['game',
#   'would',
#   'be',
#   'if',
#   'you',
#   'didn',
#   'have',
#   'to',
#   'spend',
#   'the',
#   'first',
#   'minutes',
#   'closing',
#   'the',
#   'offers',
#   'that',
#   'are',
#   'shoved',
#   'down',
#   'your',
#   'throat',
#   'when',
#   'you',
#   'open',
#   'the',
#   'game',
#   'no',
#   'option',
#   'to',
#   'disable',
#   'the',
#   'forced',
#   'offers',
#   'the',
#   'pricing',
#   'on',
#   'those',
#   'offers',
#   'are',
#   'outrageous',
#   'imagine',
#   'spending',
#   'for',
#   'gacha',
#   'crystals',
#   'and',
#   'then',
#   'getting',
#   'low',
#   'quality',
#   'characters',
#   'that',
#   'are',
#   'barely',
#   'good',
#   'enough',
#   'to',
#   'be',
#   'absorbed',
#   'for',
#   'xp'],
#  ['tldr',
#   'there',
#   'not',
#   'so',
#   'micro',
#   'transaction',
#   'for',
#   'that',
#   'free',
#   'to',
#   'play',
#   'pay',
#   'to',
#   'win',
#   'hours',
#   'day',
#   'needed',
#   'to',
#   'finish',
#   'dailys',
#   'weeks',
#   'of',
#   'farming',
#   'silver',
#   'to',
#   'level',
#   'artifact',
#   'weeks',
#   'of',
#   'farming',
#   'food',
#   'champs',
#   'months',
#   'of',
#   'saving',
#   'shards',
#   'for',
#   'miniscule',
#   'chances',
#   'at',
#   'getting',
#   'anything',
#   'useful',
#   'don',
#   'get',
#   'me',
#   'wrong',
#   'love',
#   'good',
#   'challenging',
#   'game',
#   'but',
#   'palarium',
#   'does',
#   'almost',
#   'everything',
#   'it',
#   'can',
#   'to',
#   'hinder',
#   'progress',
#   'so',
#   'that',
#   'you',
#   'give',
#   'them',
#   'money',
#   'just',
#   'check',
#   'out',
#   'the',
#   'raid',
#   'reddit',
#   'you',
#   'll',
#   'see'],
#  ['garbage',
#   'utter',
#   'garbage',
#   'gameplay',
#   'is',
#   'impossible',
#   'unless',
#   'you',
#   'pay',
#   'the',
#   'percentage',
#   'of',
#   'getting',
#   'anything',
#   'to',
#   'help',
#   'you',
#   'characters',
#   'or',
#   'otherwise',
#   'is',
#   'utterly',
#   'broken',
#   'power',
#   'levels',
#   'are',
#   'no',
#   'where',
#   'near',
#   'proper',
#   'arena',
#   'places',
#   'you',
#   'against',
#   'of',
#   'unbeatable',
#   'players',
#   'now',
#   'demon',
#   'load',
#   'payouts',
#   'suck',
#   'now',
#   'as',
#   'percentage',
#   'of',
#   'artifact',
#   'is',
#   'non',
#   'existent',
#   'don',
#   'waste',
#   'your',
#   'time',
#   'trying',
#   'to',
#   'grind',
#   'do',
#   'not',
#   'download',
#   'this'],
#  ['back',
#   'to',
#   'back',
#   'weeks',
#   'of',
#   'important',
#   'nerfs',
#   'one',
#   'unannounced',
#   'with',
#   'no',
#   'consideration',
#   'for',
#   'wasted',
#   'resources',
#   'inconsistencies',
#   'in',
#   'explanations',
#   'or',
#   'total',
#   'lack',
#   'of',
#   'communication',
#   'overall',
#   'one',
#   'of',
#   'the',
#   'greediest',
#   'run',
#   'dev',
#   'teams',
#   've',
#   'encountered',
#   'for',
#   'mobile',
#   'game',
#   'these',
#   'devs',
#   'are',
#   'disconnected',
#   'from',
#   'the',
#   'reality',
#   'of',
#   'their',
#   'game',
#   'and',
#   'only',
#   'operate',
#   'for',
#   'their',
#   'bottom',
#   'line',
#   'not',
#   'player',
#   'satisfaction',
#   'explains',
#   'why',
#   'their',
#   'player',
#   'retention',
#   'rate',
#   'is',
#   'in',
#   'the',
#   'dumpster',
#   'don',
#   'be',
#   'surprised',
#   'when',
#   'long',
#   'time',
#   'players',
#   'leave',
#   'because',
#   'of',
#   'ineptitude'],
#  ['being',
#   'bombarded',
#   'with',
#   'multiple',
#   'ads',
#   'for',
#   'the',
#   'shop',
#   'like',
#   'sometimes',
#   'in',
#   'row',
#   'is',
#   'just',
#   'awful',
#   'and',
#   'the',
#   'extremely',
#   'slow',
#   'way',
#   'of',
#   'leveling',
#   'up',
#   'characters',
#   'need',
#   'to',
#   'be',
#   'improved',
#   'needs',
#   'way',
#   'like',
#   'how',
#   'brave',
#   'frontier',
#   'gives',
#   'you',
#   'special',
#   'feeder',
#   'characters',
#   'to',
#   'fuse',
#   'right',
#   'now',
#   'the',
#   'cycle',
#   'to',
#   'try',
#   'get',
#   'to',
#   'end',
#   'game',
#   'takes',
#   'to',
#   'long',
#   'and',
#   'it',
#   'discouraging',
#   'to',
#   'keep',
#   'logging',
#   'in'],
#  ['fun',
#   'game',
#   'but',
#   'very',
#   'expensive',
#   'constant',
#   'glitches',
#   'and',
#   'bugs',
#   'and',
#   'don',
#   'bother',
#   'even',
#   'trying',
#   'to',
#   'contact',
#   'support',
#   'no',
#   'matter',
#   'what',
#   'you',
#   'do',
#   'the',
#   'system',
#   'will',
#   'never',
#   'allow',
#   'you',
#   'to',
#   'create',
#   'ticket',
#   'very',
#   'much',
#   'give',
#   'us',
#   'your',
#   'money',
#   'but',
#   'don',
#   'ever',
#   'think',
#   'you',
#   'mean',
#   'thing',
#   'if',
#   'you',
#   'actually',
#   'do',
#   'manage',
#   'to',
#   'send',
#   'them',
#   'information',
#   'about',
#   'the',
#   'problem',
#   'you',
#   'will',
#   'get',
#   'an',
#   'incredibly',
#   'unrelated',
#   'automated',
#   'answer',
#   'worst',
#   'customer',
#   'service',
#   'personally',
#   'have',
#   'encountered'],
#  ['started',
#   'great',
#   'when',
#   'started',
#   'the',
#   'game',
#   'was',
#   'hooked',
#   'as',
#   'in',
#   'the',
#   'mid',
#   'game',
#   'starting',
#   'to',
#   'see',
#   'its',
#   'flaws',
#   'grinding',
#   'grinding',
#   'wouldn',
#   'be',
#   'so',
#   'bad',
#   'if',
#   'you',
#   're',
#   'not',
#   'constantly',
#   'getting',
#   'everything',
#   'else',
#   'you',
#   'are',
#   'grinding',
#   'for',
#   'pay',
#   'to',
#   'play',
#   've',
#   'spent',
#   'money',
#   'on',
#   'this',
#   'game',
#   'but',
#   'now',
#   'it',
#   'feels',
#   'have',
#   'pay',
#   'every',
#   'other',
#   'day',
#   'to',
#   'progress',
#   'in',
#   'the',
#   'game',
#   'sacred',
#   'shards',
#   'the',
#   'highest',
#   'crystal',
#   'in',
#   'the',
#   'game',
#   'and',
#   'only',
#   'chance',
#   'to',
#   'pull',
#   'the',
#   'highest',
#   'tier',
#   'warrior'],
#  ['great',
#   'game',
#   'love',
#   'playing',
#   'afk',
#   'so',
#   'can',
#   'get',
#   'other',
#   'things',
#   'done',
#   'and',
#   'works',
#   'as',
#   'background',
#   'noise',
#   'it',
#   'also',
#   'has',
#   'awsome',
#   'weapons',
#   'and',
#   'armor',
#   'that',
#   'when',
#   'get',
#   'into',
#   'place',
#   'where',
#   'can',
#   'start',
#   'forging',
#   'will',
#   'be',
#   'using',
#   'this',
#   'to',
#   'inspire',
#   'my',
#   'designs',
#   'as',
#   'more',
#   'temperary',
#   'fix',
#   'will',
#   'try',
#   'making',
#   'easy',
#   'plastic',
#   'props',
#   'when',
#   'do',
#   'get',
#   'around',
#   'to',
#   'it',
#   'will',
#   'post',
#   'and',
#   'tag',
#   'the',
#   'game',
#   'and',
#   'champion',
#   'on',
#   'instagram',
#   'let',
#   'me',
#   'know',
#   'if',
#   'thats',
#   'ok',
#   'if',
#   'not',
#   'can',
#   'just',
#   'not',
#   'post',
#   'and',
#   'make',
#   'for',
#   'personal',
#   'wall',
#   'hangers'],
#  ['do',
#   'not',
#   'spend',
#   'your',
#   'money',
#   'am',
#   'so',
#   'done',
#   'with',
#   'this',
#   'ridiculous',
#   'game',
#   'extremely',
#   'poorly',
#   'tuned',
#   'bosses',
#   'that',
#   'need',
#   'one',
#   'of',
#   'couple',
#   'of',
#   'champions',
#   'with',
#   'no',
#   'other',
#   'use',
#   'in',
#   'the',
#   'game',
#   'to',
#   'cheese',
#   'the',
#   'mechanics',
#   'immediately',
#   'followed',
#   'by',
#   'moneygrab',
#   'summoning',
#   'events',
#   'for',
#   'those',
#   'exact',
#   'champions',
#   'high',
#   'powered',
#   'epic',
#   'champion',
#   'rolled',
#   'out',
#   'nerfed',
#   'into',
#   'the',
#   'ground',
#   'but',
#   'not',
#   'until',
#   'after',
#   'moneygrab',
#   'summoning',
#   'event',
#   'featuring',
#   'that',
#   'champion',
#   'play',
#   'it',
#   'if',
#   'you',
#   'must',
#   'but',
#   'keep',
#   'your',
#   'wallet',
#   'firmly',
#   'closed',
#   'to',
#   'prevent',
#   'rage',
#   'disappointment'],
#  ['have',
#   'played',
#   'this',
#   'game',
#   'for',
#   'over',
#   'months',
#   'it',
#   'mostly',
#   'fun',
#   'game',
#   'but',
#   'out',
#   'done',
#   'they',
#   'treat',
#   'their',
#   'players',
#   'like',
#   'garbage',
#   'the',
#   'most',
#   'recent',
#   'example',
#   'two',
#   'champions',
#   'geomancer',
#   'and',
#   'urogrim',
#   'which',
#   'they',
#   'let',
#   'and',
#   'encouraged',
#   'players',
#   'to',
#   'specially',
#   'purchase',
#   'three',
#   'months',
#   'ago',
#   'just',
#   'got',
#   'nerfed',
#   'hard',
#   'all',
#   'that',
#   'money',
#   'to',
#   'get',
#   'them',
#   'wasted',
#   'over',
#   'hours',
#   'of',
#   'in',
#   'game',
#   'time',
#   'spent',
#   'leveling',
#   'and',
#   'maxing',
#   'wasted',
#   'this',
#   'company',
#   'is',
#   'dumpster',
#   'fire',
#   'don',
#   'play',
#   'this',
#   'game',
#   'you',
#   'll',
#   'hate',
#   'yourself',
#   'later',
#   'know',
#   'do'],
#  ['am',
#   'free',
#   'to',
#   'play',
#   'account',
#   'and',
#   'am',
#   'able',
#   'to',
#   'make',
#   'progress',
#   'everywhere',
#   'except',
#   'the',
#   'arena',
#   'there',
#   'needs',
#   'to',
#   'be',
#   'time',
#   'limit',
#   'or',
#   'something',
#   'because',
#   'will',
#   'get',
#   'into',
#   'no',
#   'win',
#   'battle',
#   'and',
#   'lose',
#   'because',
#   'have',
#   'to',
#   'leave',
#   'it',
#   'cause',
#   'neither',
#   'opponent',
#   'can',
#   'kill',
#   'the',
#   'other',
#   'left',
#   'it',
#   'on',
#   'auto',
#   'play',
#   'one',
#   'night',
#   'and',
#   'it',
#   'was',
#   'still',
#   'fighting',
#   'hours',
#   'later',
#   'update',
#   'fixed',
# ...
#   'up',
#   'your',
#   'scared',
#   'shards',
#   'to',
#   'consistently',
#   'get',
#   'the',
#   'same',
#   'darn',
#   'champions',
#   'the',
#   'game',
#   'is',
#   'designed',
#   'for',
#   'you',
#   'to',
#   'spend',
#   'money',
#   'and',
#   'even',
#   'when',
#   'you',
#   'do',
#   'it',
#   'still',
#   'works',
#   'against',
#   'you',
#   'plarium',
#   'has',
#   'developed',
#   'based',
#   'on',
#   'greed',
#   'the',
#   'graphics',
#   'are',
#   'great',
#   'and',
#   'the',
#   'concept',
#   'is',
#   'very',
#   'simple',
#   'but',
#   'don',
#   'waste',
#   'your',
#   'time'],
#  ['what',
#   'makes',
#   'this',
#   'game',
#   'really',
#   'frustrating',
#   'is',
#   'the',
#   'bombardment',
#   'of',
#   'dozen',
#   'ads',
#   'if',
#   'want',
#   'to',
#   'pay',
#   'for',
#   'something',
#   'know',
#   'where',
#   'to',
#   'go',
#   'it',
#   'absolutely',
#   'annoying',
#   'that',
#   'everytime',
#   'login',
#   'have',
#   'to',
#   'hit',
#   'the',
#   'times',
#   'before',
#   'play'],
#  ['fail',
#   'rate',
#   'at',
#   'legendary',
#   'character',
#   'years',
#   'in',
#   'and',
#   'have',
#   'handful',
#   'that',
#   'weren',
#   'free',
#   'for',
#   'legendary',
#   'shard',
#   'with',
#   'almost',
#   'certainty',
#   'of',
#   'throwing',
#   'your',
#   'money',
#   'away',
#   'update',
#   'your',
#   'system',
#   'spend',
#   'more',
#   'money',
#   'if',
#   'guaranteed',
#   'something',
#   'in',
#   'return',
#   'other',
#   'than',
#   'blown',
#   'out',
#   'anus',
#   'and',
#   'wallet'],
#  ['had',
#   'to',
#   'take',
#   'away',
#   'star',
#   'great',
#   'game',
#   'fun',
#   'cool',
#   'champions',
#   'to',
#   'collect',
#   'and',
#   'build',
#   'but',
#   'is',
#   'slow',
#   'to',
#   'level',
#   'up',
#   'gear',
#   'and',
#   'shards',
#   'are',
#   'highly',
#   'over',
#   'priced',
#   'for',
#   'the',
#   'amount',
#   'of',
#   'sub',
#   'par',
#   'doubled',
#   'up',
#   'champions',
#   'they',
#   'throw',
#   'out',
#   'spend',
#   'at',
#   'least',
#   'week',
#   'and',
#   'it',
#   'is',
#   'total',
#   'bs',
#   'that',
#   'you',
#   'get',
#   'low',
#   'level',
#   'champions',
#   'that',
#   'are',
#   'basically',
#   'food',
#   'over',
#   'and',
#   'over',
#   'again',
#   'the',
#   'percentages',
#   'need',
#   'reworked',
#   'big',
#   'time',
#   'it',
#   'is',
#   'starting',
#   'to',
#   'turn',
#   'me',
#   'away',
#   'lately',
#   'and',
#   'sure',
#   'others',
#   'feel',
#   'the',
#   'same',
#   'hope',
#   'they',
#   'do',
#   'something',
#   'about',
#   'this',
#   'before',
#   'they',
#   'lose',
#   'me'],
#  ['game',
#   'has',
#   'great',
#   'depth',
#   'and',
#   'cool',
#   'team',
#   'building',
#   'opportunities',
#   'but',
#   'they',
#   'have',
#   'in',
#   'place',
#   'and',
#   'continue',
#   'to',
#   'make',
#   'changes',
#   'that',
#   'make',
#   'the',
#   'game',
#   'an',
#   'atrocious',
#   'grind',
#   'for',
#   'those',
#   'who',
#   'don',
#   'want',
#   'to',
#   'buy',
#   'their',
#   'offers',
#   'they',
#   'know',
#   'important',
#   'resources',
#   'and',
#   'they',
#   've',
#   'put',
#   'them',
#   'all',
#   'behind',
#   'paywalls',
#   'or',
#   'literal',
#   'months',
#   'of',
#   'your',
#   'time'],
#  ['while',
#   'the',
#   'game',
#   'gives',
#   'an',
#   'incredible',
#   'variety',
#   'in',
#   'champions',
#   'bosses',
#   'and',
#   'gives',
#   'you',
#   'lot',
#   'of',
#   'opportunities',
#   'to',
#   'level',
#   'up',
#   'and',
#   'ascend',
#   'it',
#   'really',
#   'hard',
#   'to',
#   'upgrade',
#   'their',
#   'rank',
#   'without',
#   'needing',
#   'to',
#   'sacrifice',
#   'number',
#   'of',
#   'champions',
#   'the',
#   'only',
#   'other',
#   'way',
#   'to',
#   'upgrade',
#   'rank',
#   'is',
#   'to',
#   'get',
#   'chickens',
#   'which',
#   'are',
#   'rare',
#   'to',
#   'stupid',
#   'level',
#   'for',
#   'those',
#   'unwilling',
#   'to',
#   'pay',
#   'it',
#   'would',
#   'make',
#   'the',
#   'game',
#   'lot',
#   'less',
#   'frustrating',
#   'if',
#   'there',
#   'were',
#   'few',
#   'more',
#   'ways',
#   'to',
#   'rank',
#   'up',
#   'champions',
#   'or',
#   'to',
#   'earn',
#   'chickens'],
#  ['love',
#   'the',
#   'idea',
#   'of',
#   'the',
#   'game',
#   'however',
#   'plarium',
#   'is',
#   'very',
#   'upfront',
#   'of',
#   'pay',
#   'win',
#   'there',
#   'are',
#   'excessive',
#   'adds',
#   'to',
#   'spend',
#   'entirely',
#   'way',
#   'to',
#   'much',
#   'money',
#   'to',
#   'give',
#   'you',
#   'slight',
#   'edge',
#   'no',
#   'packages',
#   'are',
#   'worth',
#   'the',
#   'money',
#   'enjoy',
#   'this',
#   'game',
#   'but',
#   'it',
#   'feels',
#   'like',
#   'one',
#   'giant',
#   'the',
#   'items',
#   'that',
#   'are',
#   'useful',
#   'ingame',
#   'are',
#   'either',
#   'few',
#   'and',
#   'far',
#   'between',
#   'or',
#   'you',
#   'guessed',
#   'it',
#   'expensive',
#   'mobile',
#   'games',
#   'should',
#   'never',
#   'cost',
#   'more',
#   'than',
#   'console',
#   'or',
#   'even',
#   'brand',
#   'new',
#   'game'],
#  ['plarium',
#   'is',
#   'becoming',
#   'increasingly',
#   'greedy',
#   'by',
#   'removing',
#   'ability',
#   'to',
#   'acquire',
#   'shards',
#   'and',
#   'books',
#   'required',
#   'to',
#   'build',
#   'becoming',
#   'increasingly',
#   'game',
#   'only',
#   'for',
#   'those',
#   'with',
#   'pockets',
#   'the',
#   'latest',
#   'patch',
#   'reinforces',
#   'my',
#   'rating',
#   'my',
#   'clan',
#   'is',
#   'in',
#   'mess',
#   'already',
#   'because',
#   'of',
#   'this',
#   'patch',
#   'it',
#   'should',
#   'be',
#   'backed',
#   'out',
#   'the',
#   'latest',
#   'update',
#   'will',
#   'help',
#   'the',
#   'clan',
#   'quests',
#   'bit',
#   'but',
#   'still',
#   'not',
#   'cooperative',
#   'aspect',
#   'of',
#   'the',
#   'game'],
#  ['plarium',
#   'never',
#   'listen',
#   'im',
#   'so',
#   'dissapointed',
#   'with',
#   'there',
#   'lack',
#   'of',
#   'reading',
#   'the',
#   'consumers',
#   'feedback',
#   'there',
#   'selfish',
#   'and',
#   'never',
#   'listen',
#   'our',
#   'clan',
#   'is',
#   'broken',
#   'due',
#   'to',
#   'the',
#   'stupid',
#   'individual',
#   'clan',
#   'points',
#   'the',
#   'game',
#   'doesn',
#   'reward',
#   'you',
#   'either',
#   'seriously',
#   'theres',
#   'all',
#   'this',
#   'extra',
#   'faff',
#   'which',
#   'give',
#   'you',
#   'players',
#   'experience',
#   'zero',
#   'and',
#   'if',
#   'you',
#   'want',
#   'to',
#   'keep',
#   'active',
#   'it',
#   'takes',
#   'hours',
#   'to',
#   'do',
#   'everything',
#   'reminder',
#   'to',
#   'plarium',
#   'its',
#   'mobile',
#   'game',
#   'what',
#   'are',
#   'you',
#   'thinking'],
#  ['too',
#   'much',
#   'effort',
#   'for',
#   'such',
#   'little',
#   'reward',
#   'summoning',
#   'rates',
#   'are',
#   'bismo',
#   'at',
#   'best',
#   'they',
#   'make',
#   'you',
#   'pay',
#   'for',
#   'more',
#   'auto',
#   'runs',
#   'absurd',
#   'and',
#   'they',
#   'certainly',
#   'pray',
#   'on',
#   'people',
#   'who',
#   'have',
#   'gambling',
#   'issues',
#   'there',
#   'should',
#   'be',
#   'way',
#   'to',
#   'turn',
#   'off',
#   'the',
#   'the',
#   'ads',
#   'when',
#   'you',
#   'log',
#   'on',
#   'to',
#   'the',
#   'game',
#   'stellar',
#   'graphics',
#   'good',
#   'looking',
#   'champions',
#   'want',
#   'to',
#   'play',
#   'the',
#   'game',
#   'but',
#   'know',
#   'it',
#   'best',
#   'if',
#   'don'],
#  ['game',
#   'is',
#   'continually',
#   'catering',
#   'to',
#   'the',
#   'of',
#   'players',
#   'who',
#   'spend',
#   'hundreds',
#   'month',
#   'on',
#   'this',
#   'game',
#   'while',
#   'removing',
#   'all',
#   'possible',
#   'rewards',
#   'for',
#   'those',
#   'of',
#   'us',
#   'who',
#   'do',
#   'not',
#   'pay',
#   'or',
#   'apparently',
#   'do',
#   'not',
#   'pay',
#   'enough',
#   'recently',
#   'bought',
#   'out',
#   'by',
#   'literal',
#   'online',
#   'casino',
#   'the',
#   'game',
#   'only',
#   'cares',
#   'about',
#   'those',
#   'willing',
#   'to',
#   'pay',
#   'money',
#   'and',
#   'continues',
#   'to',
#   'decrease',
#   'the',
#   'rewards',
#   'for',
#   'all',
#   'other',
#   'players',
#   'this',
#   'is',
#   'exactly',
#   'the',
#   'way',
#   'to',
#   'ruin',
#   'what',
#   'used',
#   'to',
#   'be',
#   'an',
#   'enjoyable',
#   'game',
#   'dont',
#   'invest',
#   'your',
#   'money',
#   'unless',
#   'you',
#   'can',
#   'pay',
#   'thousands'],
#  ['palarium',
#   'there',
#   'are',
#   'so',
#   'many',
#   'logical',
#   'ways',
#   'you',
#   'could',
#   'have',
#   'done',
#   'this',
#   'to',
#   'make',
#   'your',
#   'player',
#   'base',
#   'happy',
#   'just',
#   'replace',
#   'the',
#   'brews',
#   'with',
#   'these',
#   'fragments',
#   'no',
#   'one',
#   'would',
#   'mind',
#   'but',
#   'you',
#   'intentionally',
#   'replace',
#   'the',
#   'best',
#   'rewards',
#   'for',
#   'something',
#   'no',
#   'one',
#   'wants',
#   'do',
#   'you',
#   'want',
#   'people',
#   'to',
#   'dislike',
#   'your',
#   'game',
#   'or',
#   'what',
#   'stop',
#   'putting',
#   'on',
#   'such',
#   'trash',
#   'fusions',
#   'legendries',
#   'each',
#   'pulled',
#   'legendary',
#   'should',
#   'make',
#   'you',
#   'somewhat',
#   'excited',
#   'these',
#   'trash',
#   'legendries',
#   'dilute',
#   'the',
#   'pool',
#   'add',
#   'leggo',
#   'book',
#   'to',
#   'the',
#   'login',
#   'reward',
#   'it',
#   'just',
#   'one',
#   'book'],
#  ['don',
#   'waste',
#   'your',
#   'time',
#   'dear',
#   'god',
#   'don',
#   'waste',
#   'your',
#   'money',
#   'have',
#   'gotten',
#   'no',
#   'response',
#   'from',
#   'customer',
#   'service',
#   'as',
#   'well',
#   'don',
#   'give',
#   'yourself',
#   'headache'],
#  ['recent',
#   'update',
#   'is',
#   'trash',
#   'taking',
#   'away',
#   'resources',
#   'precious',
#   'to',
#   'anyone',
#   'for',
#   'garbage',
#   'fragments',
#   'in',
#   'daily',
#   'log',
#   'in',
#   'and',
#   'the',
#   'worst',
#   'clan',
#   'system',
#   'garbage',
#   'ive',
#   'ever',
#   'seen',
#   'with',
#   'the',
#   'most',
#   'paywall',
#   'missions',
#   'ive',
#   'ever',
#   'seen',
#   'for',
#   'example',
#   'pull',
#   'epics',
#   'who',
#   'knows',
#   'how',
#   'many',
#   'shards',
#   'either',
#   'pay',
#   'for',
#   'them',
#   'or',
#   'waste',
#   'resources',
#   'for',
#   'garbage',
#   'in',
#   'their',
#   'garbage',
#   'shop',
#   'could',
#   'cost',
#   'you',
#   'more',
#   'than',
#   'to',
#   'do',
#   'gg',
#   'plarium',
#   'nailed',
#   'it',
#   'big',
#   'if',
#   'you',
#   'are',
#   'interested',
#   'in',
#   'game',
#   'save',
#   'yourself',
#   'the',
#   'trouble',
#   'and',
#   'skip',
#   'rsl',
#   'because',
#   'the',
#   'company',
#   'doesnt',
#   'care'],
#  ['so',
#   'cool',
#   'play',
#   'this',
#   'everyday',
#   'would',
#   'download',
#   'and',
#   'play',
#   'right',
#   'now',
#   'for',
#   'chance',
#   'to',
#   'win',
#   'the',
#   'champion',
#   'ninja',
#   'offer',
#   'spends',
#   'ends',
#   'oct'],
#  ['annoying',
#   'at',
#   'best',
#   'this',
#   'game',
#   'shoves',
#   'more',
#   'mtx',
#   'pop',
#   'ups',
#   'in',
#   'your',
#   'face',
#   'than',
#   'any',
#   'game',
#   'have',
#   'ever',
#   'seen',
#   'the',
#   'worst',
#   'part',
#   'is',
#   'the',
#   'packs',
#   'are',
#   'over',
#   'priced',
#   'and',
#   'the',
#   'odds',
#   'of',
#   'getting',
#   'what',
#   'you',
#   'paid',
#   'for',
#   'are',
#   'in',
#   'the',
#   'single',
#   'digits',
#   'you',
#   'are',
#   'better',
#   'off',
#   'playing',
#   'madden',
#   'ultimate',
#   'team',
#   'than',
#   'this'],
#  ['absolutely',
#   'terrible',
#   'you',
#   'annoy',
#   'ppl',
#   'into',
#   'trying',
#   'your',
#   'game',
#   'with',
#   'obnoxious',
#   'adds',
#   'all',
#   'over',
#   'internet',
#   'and',
#   'then',
#   'you',
#   'annoy',
#   'them',
#   'into',
#   'leaving',
#   'on',
#   'the',
#   'st',
#   'day',
#   'by',
#   'trying',
#   'to',
#   'rip',
#   'them',
#   'off',
#   'on',
#   'every',
#   'step',
#   'within',
#   'minutes',
#   'of',
#   'installing',
#   'was',
#   'bombarded',
#   'with',
#   'premium',
#   'packages',
#   'on',
#   'every',
#   'step',
#   'every',
#   'interface',
#   'opened',
#   'prompted',
#   'some',
#   'paid',
#   'pop',
#   'up',
#   'couldn',
#   'even',
#   'enjoy',
#   'the',
#   'game',
#   'and',
#   'see',
#   'what',
#   'it',
#   'about',
#   'before',
#   'you',
#   'try',
#   'to',
#   'scam',
#   'me',
#   'into',
#   'spending',
#   'hundreds',
#   'of',
#   'playing',
#   'is',
#   'like',
#   'browsing',
#   'some',
#   'shifty',
#   'websites',
#   'without',
#   'addblock'],
#  ['it',
#   'fun',
#   'and',
#   'there',
#   'lots',
#   'of',
#   'champions',
#   'and',
#   'new',
#   'ones',
#   'coming',
#   'start',
#   'playing',
#   'the',
#   'game',
#   'once',
#   'you',
#   'play',
#   'you',
#   'get',
#   'addicted'],
#  ['not',
#   'as',
#   'awful',
#   'as',
#   'the',
#   'horrendously',
#   'obnoxious',
#   'advertisements',
#   'make',
#   'it',
#   'out',
#   'to',
#   'be',
#   'it',
#   'not',
#   'strategy',
#   'game',
#   'or',
#   'an',
#   'rpg',
#   'it',
#   'hero',
#   'management',
#   'sim',
#   'overall',
#   'fairly',
#   'decent',
#   'mobile',
#   'game',
#   'the',
#   'one',
#   'glaringly',
#   'obvious',
#   'downside',
#   'is',
#   'the',
#   'horrendous',
#   'game',
#   'design',
#   'for',
#   'the',
#   'spider',
#   'boss',
#   'if',
#   'fight',
#   'is',
#   'mins',
#   'long',
#   'min',
#   'and',
#   'secs',
#   'will',
#   'be',
#   'spent',
#   'waiting',
#   'for',
#   'the',
#   'boss',
#   'to',
#   'spawn',
#   'small',
#   'spiders',
#   'at',
#   'time',
#   'over',
#   'and',
#   'over',
#   'and',
#   'then',
#   'waiting',
#   'for',
#   'each',
#   'of',
#   'them',
#   'to',
#   'attack',
#   'individually',
#   'which',
#   'is',
#   'unnecessary',
#   'as',
#   'they',
#   'all',
#   'attack',
#   'unit'],
#  ['this',
#   'company',
#   'is',
#   'very',
#   'greedy',
#   'and',
#   'predatory',
#   'if',
#   'you',
#   'have',
#   'struggles',
#   'with',
#   'compulsive',
#   'purchases',
#   'or',
#   'like',
#   'to',
#   'play',
#   'for',
#   'free',
#   'look',
#   'elsewhere',
#   'their',
#   'entire',
#   'plan',
#   'is',
#   'to',
#   'give',
#   'you',
#   'just',
#   'enough',
#   'free',
#   'stuff',
#   'to',
#   'keep',
#   'you',
#   'interested',
#   'but',
#   'never',
#   'enough',
#   'to',
#   'complete',
#   'events',
#   'their',
#   'most',
#   'recent',
#   'announced',
#   'change',
#   'is',
#   'to',
#   'make',
#   'the',
#   'daily',
#   'login',
#   'rewards',
#   'slightly',
#   'worse',
#   'edit',
#   'to',
#   'clarify',
#   'they',
#   'are',
#   'removing',
#   'expensive',
#   'resources',
#   'from',
#   'the',
#   'monthly',
#   'rewards',
#   'so',
#   'you',
#   'can',
#   'get',
#   'guaranteed',
#   'possibly',
#   'dupe',
#   'champion',
#   'over',
#   'months'],
#  ['get',
#   'that',
#   'new',
#   'player',
#   'need',
#   'it',
#   'but',
#   'is',
#   'there',
#   'way',
#   'to',
#   'skip',
#   'the',
#   'tutorial',
#   'if',
#   'you',
#   'already',
#   'played',
#   'it',
#   'suck',
#   'to',
#   'have',
#   'to',
#   'be',
#   'forced',
#   'to',
#   'sit',
#   'throught',
#   'this',
#   'much',
#   'of',
#   'pointless',
#   'part',
#   'of',
#   'the',
#   'game',
#   'if',
#   'it',
#   'been',
#   'played',
#   'once',
#   'on',
#   'different',
#   'device',
#   'like',
#   'pc',
#   'or',
#   'tablet',
#   'the',
#   'tutorial',
#   'to',
#   'this',
#   'game',
#   'is',
#   'like',
#   'every',
#   'other',
#   'tutorial',
#   'to',
#   'games',
#   'like',
#   'it',
#   'is',
#   'just',
#   'repeat',
#   'the',
#   'same',
#   'thing',
#   'over',
#   'and',
#   'over',
#   'again',
#   'so',
#   'make',
#   'something',
#   'new',
#   'and',
#   'original'],
#  ['one',
#   'of',
#   'the',
#   'most',
#   'pay',
#   'to',
#   'win',
#   'games',
#   'out',
#   'you',
#   'll',
#   'need',
#   'minimum',
#   'of',
#   'spent',
#   'to',
#   'be',
#   'semi',
#   'competitive',
#   'and',
#   'probably',
#   'closer',
#   'to',
#   'or',
#   'if',
#   'you',
#   'want',
#   'to',
#   'be',
#   'competitive',
#   'in',
#   'the',
#   'first',
#   'year',
#   'you',
#   'play',
#   'they',
#   'are',
#   'taking',
#   'away',
#   'all',
#   'the',
#   'good',
#   'free',
#   'things',
#   'and',
#   'replacing',
#   'them',
#   'with',
#   'useless',
#   'rewards',
#   'that',
#   'don',
#   'help',
#   'you',
#   'at',
#   'all',
#   'finally',
#   'you',
#   'need',
#   'to',
#   'play',
#   'atleast',
#   'hours',
#   'day',
#   'just',
#   'to',
#   'do',
#   'the',
#   'basic',
#   'stuff',
#   'or',
#   'you',
#   'miss',
#   'out',
#   'to',
#   'be',
#   'competitive',
#   'you',
#   'll',
#   'need',
#   'an',
#   'auto',
#   'clicker',
#   'and',
#   'atleast',
#   'hours',
#   'day',
#   'afk',
#   'farming',
#   'gear'],
#  ['based',
#   'on',
#   'the',
#   'normal',
#   'cost',
#   'of',
#   'sacred',
#   'shard',
#   'and',
#   'your',
#   'odds',
#   'of',
#   'pulling',
#   'one',
#   'from',
#   'shard',
#   'plarium',
#   'thinks',
#   'each',
#   'legendary',
#   'champion',
#   'is',
#   'usd',
#   'finding',
#   'myself',
#   'playing',
#   'much',
#   'less',
#   'because',
#   'the',
#   'joy',
#   'of',
#   'winning',
#   'things',
#   'if',
#   'gone',
#   'thinking',
#   'of',
#   'uninstalling',
#   'you',
#   're',
#   'response',
#   'is',
#   'exactly',
#   'what',
#   'am',
#   'referring',
#   'to',
#   'long',
#   'time',
#   'players',
#   'already',
#   'have',
#   'those',
#   'champs',
#   'and',
#   'don',
#   'need',
#   'free',
#   'duplicates',
#   'with',
#   'no',
#   'use',
#   'they',
#   'need',
#   'sacred',
#   'shards',
#   'and',
#   'books',
#   'more',
#   'than',
#   'anything'],
#  ['there',
#   'are',
#   'many',
#   'positive',
#   'aspects',
#   'of',
#   'this',
#   'game',
#   'unfortunately',
#   'they',
#   'are',
#   'undone',
#   'by',
#   'the',
#   'games',
#   'unstable',
#   'connection',
#   'and',
#   'constant',
#   'flow',
#   'of',
#   'pop',
#   'up',
#   'offers',
#   'if',
#   'these',
#   'two',
#   'seemingly',
#   'simple',
#   'problems',
#   'were',
#   'to',
#   'be',
#   'fixed',
#   'it',
#   'would',
#   'be',
#   'stars',
#   'for',
#   'sure']]

# %%
df.iloc[0]['content']
# Out:
# "Was fun while it worked, been playing for almost 2 weeks and it has a lot of potential. Plenty of options for free to play and limited pay to play style of players. Unfortunately starting late last night I was unable to login, and I tried the usual fixes (clearing cache, uninstall, contact support). But support has yet to get in contact with me. It's been approximately 26hrs and still nothing. I'm glad I don't have too much $$$ vested in this game or I would be very upset"

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['was', 'fun', 'while', 'it', 'worked', 'been', 'playing', 'for', 'almost', 'weeks', 'and', 'it', 'has', 'lot', 'of', 'potential', 'plenty', 'of', 'options', 'for', 'free', 'to', 'play', 'and', 'limited', 'pay', 'to', 'play', 'style', 'of', 'players', 'unfortunately', 'starting', 'late', 'last', 'night', 'was', 'unable', 'to', 'login', 'and', 'tried', 'the', 'usual', 'fixes', 'clearing', 'cache', 'uninstall', 'contact', 'support', 'but', 'support', 'has', 'yet', 'to', 'get', 'in', 'contact', 'with', 'me', 'it', 'been', 'approximately', 'hrs', 'and', 'still', 'nothing', 'glad', 'don', 'have', 'too', 'much', 'vested', 'in', 'this', 'game', 'or', 'would', 'be', 'very', 'upset']

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.062*"champion" + 0.050*"company" + 0.040*"resource" + 0.039*"greedy" + '
#   '0.034*"champ" + 0.027*"nerf" + 0.025*"event" + 0.022*"remove" + '
#   '0.021*"rank" + 0.019*"shop"'),
#  (1,
#   '0.078*"number" + 0.071*"push" + 0.054*"avoid" + 0.049*"grab" + '
#   '0.038*"attempt" + 0.032*"button" + 0.021*"somewhat" + 0.018*"count" + '
#   '0.012*"dull" + 0.011*"practice"'),
#  (2,
#   '0.106*"pvp" + 0.077*"cause" + 0.071*"luck" + 0.040*"access" + 0.028*"boost" '
#   '+ 0.019*"tough" + 0.014*"loose" + 0.000*"cancel" + 0.000*"banner" + '
#   '0.000*"random"'),
#  (3,
#   '0.170*"response" + 0.077*"horrible" + 0.016*"rsl" + 0.000*"deal" + '
#   '0.000*"comment" + 0.000*"sacred_shard" + 0.000*"show" + 0.000*"bot" + '
#   '0.000*"devs" + 0.000*"contradict"'),
#  (4,
#   '0.100*"fix" + 0.083*"energy" + 0.058*"gear" + 0.043*"turn" + 0.039*"base" + '
#   '0.038*"power" + 0.037*"rating" + 0.035*"happen" + 0.034*"mission" + '
#   '0.032*"hit"'),
#  (5,
#   '0.090*"scam" + 0.082*"bore" + 0.034*"write" + 0.033*"balanced" + '
#   '0.020*"bombarded" + 0.017*"fantasy" + 0.014*"endless" + 0.007*"tone" + '
#   '0.006*"fighting" + 0.000*"step"'),
#  (6,
#   '0.109*"come" + 0.083*"ancient" + 0.063*"m" + 0.060*"definitely" + '
#   '0.049*"complaint" + 0.034*"obtain" + 0.028*"device" + 0.027*"ago" + '
#   '0.027*"today" + 0.019*"material"'),
#  (7,
#   '0.115*"shard" + 0.075*"legendary" + 0.052*"clan" + 0.037*"chance" + '
#   '0.034*"summon" + 0.033*"pull" + 0.032*"quest" + 0.028*"chicken" + '
#   '0.025*"epic" + 0.024*"sacred"'),
#  (8,
#   '0.214*"log" + 0.046*"armor" + 0.041*"guess" + 0.036*"sometimes" + '
#   '0.033*"scroll" + 0.031*"key" + 0.029*"patience" + 0.021*"multiple" + '
#   '0.021*"lucky" + 0.012*"man"'),
#  (9,
#   '0.086*"game" + 0.039*"get" + 0.031*"play" + 0.021*"money" + 0.020*"time" + '
#   '0.018*"spend" + 0.016*"make" + 0.016*"good" + 0.014*"pay" + 0.013*"player"'),
#  (10,
#   '0.082*"nice" + 0.077*"ask" + 0.063*"everytime" + 0.042*"skip" + '
#   '0.022*"legend" + 0.021*"beautiful" + 0.020*"draw" + 0.019*"uninstalled" + '
#   '0.018*"disappointing" + 0.018*"info"'),
#  (11,
#   '0.126*"use" + 0.107*"battle" + 0.071*"auto" + 0.068*"able" + 0.036*"total" '
#   '+ 0.035*"dev" + 0.023*"reasonable" + 0.022*"line" + 0.022*"totally" + '
#   '0.016*"depend"'),
#  (12,
#   '0.045*"slot" + 0.038*"automate" + 0.030*"opinion" + 0.023*"state" + '
#   '0.019*"changed" + 0.017*"headache" + 0.012*"machine" + 0.012*"land" + '
#   '0.012*"trust" + 0.011*"search"'),
#  (13,
#   '0.093*"decide" + 0.043*"card" + 0.000*"cancel" + 0.000*"subscription" + '
#   '0.000*"dupe" + 0.000*"sacred_shard" + 0.000*"step" + 0.000*"develop" + '
#   '0.000*"crazy" + 0.000*"sarcasticly"'),
#  (14,
#   '0.113*"drop" + 0.085*"guy" + 0.071*"replace" + 0.053*"literally" + '
#   '0.042*"reduce" + 0.041*"aspect" + 0.037*"fragment" + 0.034*"come" + '
#   '0.025*"blue" + 0.018*"claim"'),
#  (15,
#   '0.084*"constant" + 0.070*"ruin" + 0.055*"s" + 0.041*"exactly" + '
#   '0.026*"percentage" + 0.025*"mostly" + 0.022*"personally" + '
#   '0.020*"ridiculously" + 0.020*"afk" + 0.019*"regardless"'),
#  (16,
#   '0.000*"disguise" + 0.000*"attitude" + 0.000*"website" + 0.000*"statistic" + '
#   '0.000*"pricea" + 0.000*"asset" + 0.000*"adjust" + 0.000*"slightly" + '
#   '0.000*"press" + 0.000*"allot"'),
#  (17,
#   '0.070*"hero" + 0.051*"purchase" + 0.040*"work" + 0.038*"pop" + '
#   '0.034*"offer" + 0.032*"ridiculous" + 0.032*"close" + 0.026*"single" + '
#   '0.024*"login" + 0.022*"overall"'),
#  (18,
#   '0.204*"first" + 0.111*"download" + 0.082*"break" + 0.034*"micro" + '
#   '0.021*"non" + 0.017*"prompt" + 0.016*"barrage" + 0.010*"proper" + '
#   '0.006*"aside" + 0.002*"plain"'),
#  (19,
#   '0.113*"pass" + 0.023*"extra" + 0.000*"second" + 0.000*"listen" + '
#   '0.000*"wonderful" + 0.000*"benefit" + 0.000*"catter" + 0.000*"diablo" + '
#   '0.000*"youtube" + 0.000*"imp"')]

# %%
df_bad = df[(df['score'] == 1) | (df['score'] == 2)]
df_good = df[(df['score'] == 4) | (df['score'] == 5)]

# %%
data_words_b = list(sent_to_words(df_bad['content']))
data_words_g = list(sent_to_words(df_good['content']))

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words_b, min_count=5, threshold=1) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words_b], threshold=1)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
#print(trigram_mod[bigram_mod[data_words[0]]])

# Remove Stop Words
data_words_nostops = remove_stopwords(data_words_b)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.235*"log" + 0.046*"fair" + 0.035*"hate" + 0.018*"compensation" + '
#   '0.015*"excuse" + 0.014*"note" + 0.010*"cache" + 0.008*"hide" + '
#   '0.007*"password" + 0.007*"unprofessional"'),
#  (1,
#   '0.097*"gameplay" + 0.058*"pretty" + 0.045*"app" + 0.042*"overall" + '
#   '0.039*"fail" + 0.036*"reason" + 0.033*"simple" + 0.033*"purchase" + '
#   '0.021*"usd" + 0.020*"device"'),
#  (2,
#   '0.114*"listen" + 0.102*"community" + 0.068*"developer" + 0.050*"feedback" + '
#   '0.041*"friendly" + 0.032*"mind" + 0.032*"aspect" + 0.026*"shop" + '
#   '0.022*"server" + 0.020*"real"'),
#  (3,
#   '0.056*"game" + 0.036*"play" + 0.031*"player" + 0.024*"update" + '
#   '0.021*"change" + 0.020*"star" + 0.019*"new" + 0.019*"make" + 0.019*"clan" + '
#   '0.018*"go"'),
#  (4,
#   '0.044*"access" + 0.037*"result" + 0.036*"mostly" + 0.024*"luck" + '
#   '0.016*"damage" + 0.009*"smh" + 0.006*"register" + 0.004*"regardless" + '
#   '0.003*"technology" + 0.003*"advancement"'),
#  (5,
#   '0.047*"single" + 0.042*"bug" + 0.035*"matter" + 0.032*"power" + '
#   '0.031*"rank" + 0.025*"pass" + 0.025*"yet" + 0.020*"send" + '
#   '0.020*"incredibly" + 0.020*"information"'),
#  (6,
#   '0.047*"honest" + 0.044*"effort" + 0.024*"hours_day" + 0.020*"horrendous" + '
#   '0.017*"yr" + 0.003*"finishing" + 0.000*"freeze" + 0.000*"shut" + '
#   '0.000*"phone" + 0.000*"cap"'),
#  (7,
#   '0.000*"dungeon" + 0.000*"likelihood" + 0.000*"forum" + 0.000*"hell" + '
#   '0.000*"hypocritical" + 0.000*"offender" + 0.000*"youtuber" + 0.000*"smear" '
#   '+ 0.000*"entrench" + 0.000*"appeal"'),
#  (8,
#   '0.075*"good_game" + 0.046*"fight" + 0.039*"dev" + 0.036*"attempt" + '
#   '0.027*"line" + 0.022*"easily" + 0.022*"limited_time" + 0.021*"bottom" + '
#   '0.020*"sort" + 0.020*"powerful"'),
#  (9,
#   '0.091*"game" + 0.050*"get" + 0.029*"time" + 0.028*"play" + 0.026*"reward" + '
#   '0.023*"make" + 0.022*"good" + 0.022*"spend" + 0.021*"money" + 0.020*"take"'),
#  (10,
#   '0.041*"get" + 0.036*"pay" + 0.033*"game" + 0.032*"shard" + 0.020*"level" + '
#   '0.019*"win" + 0.018*"even" + 0.018*"bad" + 0.017*"champion" + '
#   '0.017*"legendary"'),
#  (11,
#   '0.088*"add" + 0.082*"pop_up" + 0.062*"pop" + 0.054*"close" + 0.034*"turn" + '
#   '0.030*"expect" + 0.030*"great_game" + 0.025*"horrible" + 0.024*"developer" '
#   '+ 0.024*"avoid"'),
#  (12,
#   '0.037*"business" + 0.037*"customer" + 0.032*"ground" + 0.032*"champion" + '
#   '0.027*"event" + 0.022*"predatory" + 0.020*"case" + 0.019*"nerfe" + '
#   '0.018*"nerfed" + 0.018*"creator"'),
#  (13,
#   '0.069*"hope" + 0.061*"decide" + 0.045*"set" + 0.026*"atleast" + '
#   '0.022*"learn" + 0.021*"address" + 0.020*"simply" + 0.020*"crash" + '
#   '0.017*"card" + 0.016*"challenge"'),
#  (14,
#   '0.080*"patch" + 0.050*"speed" + 0.048*"kill" + 0.037*"stay" + '
#   '0.033*"dupe_system" + 0.024*"shadow" + 0.023*"intend" + 0.022*"state" + '
#   '0.022*"devs" + 0.019*"building"'),
#  (15,
#   '0.038*"bore" + 0.026*"bombarded" + 0.012*"fantasy" + 0.012*"shallow" + '
#   '0.003*"hundreds" + 0.003*"astronomically" + 0.003*"theme" + '
#   '0.003*"disguised" + 0.003*"endless" + 0.003*"deliberately"'),
#  (16,
#   '0.046*"champion" + 0.041*"month" + 0.037*"nerf" + 0.032*"champ" + '
#   '0.027*"ever" + 0.024*"guarantee" + 0.023*"resource" + 0.018*"release" + '
#   '0.016*"people" + 0.016*"company"'),
#  (17,
#   '0.109*"hero" + 0.065*"quest" + 0.041*"complete" + 0.025*"hit" + '
#   '0.023*"like" + 0.019*"gold" + 0.019*"check" + 0.018*"draw" + 0.017*"finish" '
#   '+ 0.015*"reasonable"'),
#  (18,
#   '0.051*"replace" + 0.048*"decent" + 0.045*"slow" + 0.031*"tier" + '
#   '0.028*"fragment" + 0.025*"plan" + 0.021*"bit" + 0.021*"sale" + '
#   '0.020*"trash" + 0.019*"still"'),
#  (19,
#   '0.106*"mission" + 0.096*"auto" + 0.043*"claim" + 0.018*"moment" + '
#   '0.009*"arbiter" + 0.003*"imposible" + 0.003*"block" + 0.000*"add" + '
#   '0.000*"guide" + 0.000*"position"')]
